# %%
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS
hugo = API_Hugo_OSS()

# %%
hugo.df_participants().columns
# Out:
# Index(['chapter_leader', 'company', 'email', 'eventbrite_id', 'facebook',
#        'featured', 'image', 'interested in', 'interested_in', 'job_title',
#        'linkedin', 'night_day', 'night_room', 'night_where', 'notes',
#        'owasp_leadership', 'pre-summit', 'project_contributor',
#        'project_leader', 'project_user', 'role', 'sessions', 'sponsored_by',
#        'status', 'test_field', 'title', 'tracks', 'travel-from', 'travel_from',
#        'twitter', 'type', 'venue', 'website', 'working_sessions'],
#       dtype='object')

# %%
hugo.df_sessions()
# Out:
#                                             categories  ...                             when_time
# 0                                                  NaN  ...                                   NaN
# 1                                                  NaN  ...                                  None
# 2                                                  NaN  ...                                   NaN
# 3                                                  NaN  ...                                  DS-2
# 4                                                  NaN  ...                                  None
# 5                                                  NaN  ...                                  PM-1
# 6                                                  NaN  ...                                  PM-1
# 7                                                  NaN  ...                                  AM-1
# 8                                                  NaN  ...                                  AM-1
# ...

# %%
hugo.qgrid_participants([])
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
