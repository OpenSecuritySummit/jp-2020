# %% [markdown]
# ## this is a first view of the CSV export
#
# From the GSheet document created by John: https://docs.google.com/spreadsheets/d/1KjYydaCgeMm-Xwh3PQEeY82MQLDlJGZ-/

# %%
import osbot_jupyter

# %%
# %%HTML
#
# <iframe src="https://docs.google.com/spreadsheets/d/1KjYydaCgeMm-Xwh3PQEeY82MQLDlJGZ-/" width="100%" , height="500">
# Out:
# <iframe src="https://docs.google.com/spreadsheets/d/1KjYydaCgeMm-Xwh3PQEeY82MQLDlJGZ-/" width="100%" , height="500">

# %%
import pandas as pd
csv_file = './Session Data and Tags--20190601.xlsx - Sheet1.csv'
df_sessions = pd.read_csv(csv_file)
df_sessions
# Out:
#                                                  Title             Track  \
# 0            Creating Appsec metrics and visualisation         DevSecOps
# 1    WAFs - Understanding and measuring how they be...         DevSecOps
# 2    Writing security tests to confirm vulnerabilit...         DevSecOps
# 3                   Agile Practices for Security Teams         DevSecOps
# 4                Creating a Security Champions Network         DevSecOps
# 5                      Dealing with DevSecOps Findings         DevSecOps
# 6                     DevSecOps Maturity Model (DSOMM)         DevSecOps
# 7            From Threat Modeling to DevSecOps metrics         DevSecOps
# 8                Integrating Security Tools in the SDL         DevSecOps
# 9                                   Secrets Management         DevSecOps
# 10                            Securing the CI Pipeline         DevSecOps
# 11                       Ask me anything (AMA) on GDPR              Misc
# 12   Introduction to Cynefin Framework (Training Se...              Misc
# 13                           Third Party Due Diligence              Misc
# 14   Using graphs for GDPR mappings and visualisations              Misc
# 15           Customising the Chaos Engineering Toolkit              Misc
# 16                                 Cyber Risk Modeling              Misc
# 17                                OWASP community-docs              Misc
# 18                        Real world Chaos Engineering              Misc
# 19                                Scaling API Security              Misc
# 20                    Securing Kubernete's hosted APIs              Misc
# 21               Security Challenges - An Introduction              Misc
# 22                Security Challenges - Analyse others              Misc
# 23           Security Challenges - Analysis, Analogies              Misc
# 24   Security Challenges - Collate others' strategi...              Misc
# 25                     Security Challenges - Next step              Misc
# 26   Using Cynefin Framework making strategic secur...              Misc
# 27                                      Juice Shop 101  OWASP Juice Shop
# 28                   Juice Shop Contributor Onboarding  OWASP Juice Shop
# 29                            Juice Shop Release Night  OWASP Juice Shop
# ..                                                 ...               ...
# 74                                      SAMM - Tooling        OWASP SAMM
# 75        Creating a generic diagram of a threat model   Threat Modeling
# 76   Describe different ways of implementing TM in ...   Threat Modeling
# 77   How do we persist the information from the TM ...   Threat Modeling
# 78                         Incremental Threat Modeling   Threat Modeling
# 79   LIGHTWEIGHT PRIVACY THREAT MODELING USING LINDDUN   Threat Modeling
# 80   Lightweight privacy threat modeling using LIND...   Threat Modeling
# 81                                        Open Session   Threat Modeling
# 82                            SAMMv2 - Threat Modeling   Threat Modeling
# 83                 STATE AND FUTURE OF THREAT MODELING   Threat Modeling
# 84                       THREAT MODEL EXAMPLES PROJECT   Threat Modeling
# 85             THREAT MODEL EXAMPLES PROJECT - Part II   Threat Modeling
# 86   TOWARDS A UNIFIED WAY OF DESCRIBING THREAT MODELS   Threat Modeling
# 87                                                 NaN   Threat Modeling
# 88                                                 NaN   Threat Modeling
# 89                                                 NaN   Threat Modeling
# 90                                                 NaN   Threat Modeling
# 91                                                 NaN   Threat Modeling
# 92                                                 NaN   Threat Modeling
# 93                                                 NaN   Threat Modeling
# 94         Using Wardley Maps and Cynefin for Security      Wardley maps
# 95                           Using Wardley Maps on SOC      Wardley maps
# 96                           Wardley Maps for Security      Wardley maps
# 97                  Cell based Structures for Security      Wardley maps
# 98   Hand's on Wardley Maps creation (Training Sess...      Wardley maps
# 99     Introduction to Wardley Maps (Training Session)      Wardley maps
# 100                                  Mapping boot camp      Wardley maps
# 101  Wardley Mapping - Climatic Patterns and Using ...      Wardley maps
# 102  Wardley Mapping - Coordinating functions withi...      Wardley maps
# 103                               Strategic Challenges               NaN
#
#         Type                                      Organiser(s)  Participants  \
# 0       User                                               NaN          10.0
# 1       User                                      George Glass           0.0
# 2       User                                        Dinis Cruz          10.0
# 3    Working                                               NaN          11.0
# 4    Working                                               NaN           3.0
# 5    Working  Claudio Camerino, Francisco Novo, Rafael Jimenez           4.0
# 6    Working                                               NaN           7.0
# 7    Working                                               NaN           6.0
# 8    Working                                               NaN          10.0
# 9    Working                                   Dominik de Smit           8.0
# 10   Working                                               NaN          15.0
# 11      User                                     Tony Richards           3.0
# 12      User                                      Dave Snowden           2.0
# 13      User                                      Didar Gelici           3.0
# 14      User                                               NaN           4.0
# 15   Working                                               NaN           5.0
# 16   Working                                      Phil Huggins           3.0
# 17   Working                                   Jonathan Marcil           NaN
# 18   Working                                               NaN           7.0
# 19   Working                                               NaN           5.0
# 20   Working                                               NaN           2.0
# 21   Working                                        Nick Drage           2.0
# 22   Working                                        Nick Drage           0.0
# 23   Working                                        Nick Drage           2.0
# 24   Working                                        Nick Drage           1.0
# 25   Working                                        Nick Drage           2.0
# 26   Working                                      Dave Snowden           2.0
# 27      User                                  Bjoern Kimminich           1.0
# 28      User                                  Bjoern Kimminich           1.0
# 29      User                                  Bjoern Kimminich           3.0
# ..       ...                                               ...           ...
# 74   Working               Sebastien Deleersnyder, Bart De Win           4.0
# 75   Working                                    Steven Wierckx           NaN
# 76   Working                                    Steven Wierckx           3.0
# 77   Working                                    Steven Wierckx           0.0
# 78   Working                     Irene Michlin, Steven Wierckx           0.0
# 79   Working                         Steven Wierckx, Kim Wuyts           4.0
# 80   Working                         Steven Wierckx, Kim Wuyts           NaN
# 81   Working                                    Steven Wierckx           NaN
# 82   Working            Steven Wierckx, Sebastien Deleersnyder           2.0
# 83   Working                                    Steven Wierckx           8.0
# 84   Working                      Jonathan Marcil, Tash Norris           1.0
# 85   Working                      Jonathan Marcil, Tash Norris           1.0
# 86   Working                                    Steven Wierckx           6.0
# 87   Working                                               NaN           NaN
# 88   Working                                               NaN           NaN
# 89   Working                                               NaN           NaN
# 90   Working                                               NaN           NaN
# 91   Working                                               NaN           NaN
# 92   Working                                               NaN           NaN
# 93   Working                                               NaN           NaN
# 94      User                      Simon Wardley , Dave Snowden           2.0
# 95      User                                     Tony Richards           5.0
# 96      User                        Mario Platt, Tony Richards           4.0
# 97   Working                      Simon Wardley, Tony Richards           2.0
# 98   Working                                     Tony Richards           3.0
# 99   Working                                     Tony Richards           2.0
# 100  Working                                     Simon Wardley           3.0
# 101  Working                                     Simon Wardley           4.0
# 102  Working                                     Simon Wardley           2.0
# 103  Keynote                                        Nick Drage           NaN
#
#      Remote Participants  Day              Time Synopsis? Locked? OWASP Type  \
# 0                    0.0  Wed              PM-1       Yes      No   Defender
# 1                    0.0  NaN               NaN        No      No   Defender
# 2                    1.0  Thu              PM-1        No      No    Builder
# 3                    2.0  Tue              PM-1       Yes      No   Defender
# 4                    0.0  Wed              AM-1       Yes      No    Builder
# 5                    3.0  Wed        PM-1, PM-2       Yes      No   Defender
# 6                    1.0  Tue  PM-1, PM-2, PM-3      Yes?      No    Builder
# 7                    3.0  Thu              PM-1        No      No   Defender
# 8                    2.0  Thu        AM-1, PM-1       Yes      No    Builder
# 9                    1.0  Wed              PM-1       Yes      No    Builder
# 10                   1.0  Thu        PM-2, PM-3       Yes      No    Builder
# 11                   0.0  Tue              PM-1       Yes      No   Defender
# 12                   0.0  Wed              AM-1        No      No        All
# 13                   0.0  Thu              DS-2        No      No   Defender
# 14                   0.0  Thu              PM-3       Yes      No   Defender
# 15                   0.0  Fri              PM-1       Yes      No   Defender
# 16                   1.0  Thu              PM-3        No      No   Defender
# 17                   NaN  NaN               NaN       Yes      No        All
# 18                   1.0  Fri              PM-3       Yes      No   Defender
# 19                   1.0  Thu              DS-2        No      No   Defender
# 20                   0.0  Thu              DS-2        No      No   Defender
# 21                   0.0  Mon              PM-1        No      No        All
# 22                   0.0  Wed               NaN       Yes      No        All
# 23                   0.0  Tue              PM-1       Yes      No        All
# 24                   0.0  Thu              PM-1       Yes      No        All
# 25                   0.0  Fri              PM-1       Yes      No        All
# 26                   0.0  Wed              PM-1        No      No        All
# 27                   0.0  Tue              AM-1       Yes      No    Builder
# 28                   0.0  Tue              PM-1       Yes      No    Builder
# 29                   0.0  Thu      Eve-1, Eve-2       Yes      No    Builder
# ..                   ...  ...               ...       ...     ...        ...
# 74                   0.0  Fri              AM-1       Yes     Yes   Builders
# 75                   NaN  Tue              PM-1       Yes     Yes    Builder
# 76                   2.0  Wed              PM-2       Yes     Yes    Builder
# 77                   2.0  Tue              AM-1       Yes     Yes    Builder
# 78                   0.0  Thu              PM-1       Yes     Yes    Builder
# 79                   1.0  Mon              PM-2       Yes     Yes    Builder
# 80                   NaN  Mon              PM-3       Yes      No    Builder
# 81                   NaN  NaN               NaN       NaN     NaN        NaN
# 82                   1.0  Thu              PM-3       Yes     Yes    Builder
# 83                   3.0  Thu              AM-1       Yes     Yes    Builder
# 84                   0.0  Wed              PM-3       Yes     Yes    Builder
# 85                   0.0  Thu              PM-3       Yes     Yes    Builder
# 86                   4.0  Thu              PM-1       Yes     Yes    Builder
# 87                   NaN  NaN               NaN       NaN     NaN        NaN
# 88                   NaN  NaN               NaN       NaN     NaN        NaN
# 89                   NaN  NaN               NaN       NaN     NaN        NaN
# 90                   NaN  NaN               NaN       NaN     NaN        NaN
# 91                   NaN  NaN               NaN       NaN     NaN        NaN
# 92                   NaN  NaN               NaN       NaN     NaN        NaN
# 93                   NaN  NaN               NaN       NaN     NaN        NaN
# 94                   0.0  Wed              PM-2        No     Yes        All
# 95                   1.0  Wed              PM-3       Yes     Yes        All
# 96                   0.0  Wed              PM-2       Yes     Yes        All
# 97                   1.0  Thu              AM-2       Yes     Yes        All
# 98                   0.0  Mon              PM-3       Yes      No        All
# 99                   0.0  Mon              PM-1       Yes      No        All
# 100                  1.0  Thu              AM-1       Yes     Yes        All
# 101                  1.0  Thu              PM-2       Yes     Yes        All
# 102                  0.0  Thu              PM-3       Yes     Yes        All
# 103                  NaN  Mon              DS-2       NaN     NaN        NaN
#
#     CSF Category SAMM 2.0 Practice & Stream  \
# 0          ID.GV                     G-SM-B
# 1          PR.PT                     O-EM-A
# 2          RS.MI                     O-EM-B
# 3          PR.IP                     G-PC-A
# 4          PR.AT                     G-EG-B
# 5          RS.MI                     I-DM-A
# 6          ID.GV                        All
# 7          PR.IP                     G-SM-B
# 8          PR.IP                     V-ST-A
# 9          PR.AC                     I-SD-B
# 10         PR.IP                     I-SD-A
# 11         ID.GV                     G-PC-B
# 12         ID.GV                     G-SM-B
# 13         ID.GV                     G-PC-B
# 14         ID.GV                     G-PC-B
# 15         DE.AE                     V-ST-A
# 16         ID.RM                     D-TA-A
# 17         PR.AT                     G-EG-B
# 18         DE.AE                     V-ST-A
# 19         PR.PT                     V-ST-A
# 20         PR.PT                     O-EM-A
# 21           NaN                        NaN
# 22           NaN                        NaN
# 23           NaN                        NaN
# 24           NaN                        NaN
# 25           NaN                        NaN
# 26         ID.GV                     G-SM-B
# 27         PR.AT                     G-EG-A
# 28         PR.AT                     G-EG-A
# 29         PR.AT                     G-EG-A
# ..           ...                        ...
# 74         ID.GV                        All
# 75         ID.GV                     D-TA-B
# 76         ID.GV                     D-TA-B
# 77         ID.GV                     D-TA-B
# 78         ID.GV                     D-TA-B
# 79         PR.AT                     G-AT-A
# 80         PR.AT                     G-AT-A
# 81           NaN                     D-TA-B
# 82         ID.GV                     D-TA-B
# 83         PR.AT                     G-AT-A
# 84         PR.AT                     G-AT-A
# 85         PR.AT                     G-AT-A
# 86         ID.GV                     D-TA-B
# 87           NaN                        NaN
# 88           NaN                        NaN
# 89           NaN                        NaN
# 90           NaN                        NaN
# 91           NaN                        NaN
# 92           NaN                        NaN
# 93           NaN                        NaN
# 94         ID.BE                        NaN
# 95         ID.BE                        NaN
# 96         ID.BE                        NaN
# 97         ID.BE                        NaN
# 98         ID.BE                        NaN
# 99         ID.BE                        NaN
# 100        ID.BE                        NaN
# 101        ID.BE                        NaN
# 102        ID.BE                        NaN
# 103          NaN                        NaN
#
#                                                   Tags  \
# 0                                              Metrics
# 1                              Metrics, Infrastructure
# 2                    Testing, Vulnerability Management
# 3                      Agile, SDLC, Program Management
# 4                        Education, Program Management
# 5                                    Defect Management
# 6                                      Maturity Models
# 7              Metrics, Threat Modeling, Visualization
# 8    SDLC, Automation?, Education?, Program Management
# 9                                       Infrastructure
# 10                                    Automation, SDLC
# 11                              Compliance, GDPR, CISO
# 12               Cynefin Framework, Project Management
# 13                            Project Management, SDLC
# 14                                 GDPR, Visualization
# 15                                             Testing
# 16                               Risk Management, CISO
# 17                             Outreach, Documentation
# 18                   API Security, Testing, Automation
# 19                        API Security, Infrastructure
# 20                        API Security, Infrastructure
# 21                                Strategic Challenges
# 22                                Strategic Challenges
# 23                                Strategic Challenges
# 24                                Strategic Challenges
# 25                                Strategic Challenges
# 26               Cynefin Framework, Project Management
# 27                        Education, Hands-on Learning
# 28                        Education, Hands-on Learning
# 29                        Education, Hands-on Learning
# ..                                                 ...
# 74                           SAMM, Governance, Metrics
# 75                                                 NaN
# 76                                     Threat Modeling
# 77                                     Threat Modeling
# 78                                     Threat Modeling
# 79                                     Threat Modeling
# 80                                     Threat Modeling
# 81                                     Threat Modeling
# 82                                     Threat Modeling
# 83                                     Threat Modeling
# 84                                     Threat Modeling
# 85                                     Threat Modeling
# 86                                     Threat Modeling
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94                        Wardley map, risk management
# 95                        Wardley map, risk management
# 96                        Wardley map, risk management
# 97                        Wardley map, risk management
# 98                        Wardley map, risk management
# 99                        Wardley map, risk management
# 100                       Wardley map, risk management
# 101                       Wardley map, risk management
# 102                       Wardley map, risk management
# 103                                                NaN
#
#                                                  Notes
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17   No day entered in MarkDown file, times entered...
# 18   Session is scheduled for Friday at 4:30 p.m. -...
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22   Meant to be an on-your-own, all-day session - ...
# 23                                                 NaN
# 24   Meant to be the "compare notes" session, after...
# 25   Meant to be the final wrap-up session for the ...
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 74                                                 NaN
# 75                                                 NaN
# 76                          Time change not merged yet
# 77                                                 NaN
# 78                                         New session
# 79                                                 NaN
# 80                     new session, needs to be merged
# 81                                  Can all be removed
# 82   Conflict with other session, can this be moved...
# 83                                                 NaN
# 84                                Updates to be merged
# 85                     new session, needs to be merged
# 86                          Time change not merged yet
# 87                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 94       Double booking with Wardley Maps for Security
# 95                                                 NaN
# 96                   Double booking with previous line
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
# 103  The time entry needs to be corrected, it's cur...
#
# [104 rows x 15 columns]

# %%
import qgrid
columns = ['Title', 'Tracl']
qgrid.show_grid(df_sessions)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
