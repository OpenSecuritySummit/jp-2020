# %%
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

import pandas as pd

# pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', None)

hugo = API_Hugo_OSS()
hugo.df_sessions()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-04dfdf308cbf> in <module>
# ----> 1 from oss2020.notebooks.api.oss_hugo import API_Hugo_OSS
#       2
#       3 import pandas as pd
#       4
#       5 # pd.set_option('display.max_colwidth', -1)
#
# ModuleNotFoundError: No module named 'oss2020'

# %%
from oss2020/notebooks/api/oss_hugo import OSS_Participant;

OSS_Participant.Hugo_Page.load(all)
# Out:
#   File "<ipython-input-3-2c31fef7dab6>", line 1
#     from oss2020/notebooks/api/oss_hugo import OSS_Participant;
#                 ^
# SyntaxError: invalid syntax

# %%
from osbot_jira.api.jira_server.API_Jira import API_Jira
api_jira = API_Jira()

# %%
api_jira = API_Jira()
features = api_jira.search('PROJECT=FEATURE')
stories = api_jira.search('PROJECT=STORY')
tasks = api_jira.search('PROJECT=TASK')

pd.set_option('display.max_rows', 999999)

print('\n\n')

print('FEATURES:')
display(pd.DataFrame(features).T[['Summary','Status','Creator']])
print('STORIES:')
display(pd.DataFrame(stories).T[['Summary','Status','Creator']])
print('TASKS:')
display(pd.DataFrame(tasks).T[['Summary','Status','Creator']])
# Out:
# searching JIRA server for PROJECT=FEATURE , starting at 0 (for a max of -1)
# searching JIRA server for PROJECT=STORY , starting at 0 (for a max of -1)
# searching JIRA server for PROJECT=TASK , starting at 0 (for a max of -1)
# searching JIRA server for PROJECT=TASK , starting at 100 (for a max of -1)
# searching JIRA server for PROJECT=TASK , starting at 115 (for a max of -1)
#
#
#
# FEATURES:
#                                    Summary       Status            Creator
# FEATURE-5  Create and Update Website Pages  In Progress        alona reyes
# FEATURE-4  Social media content management      Backlog  Tatevik Stepanyan
# FEATURE-3   OSS website content management  In Progress  Tatevik Stepanyan
# FEATURE-2               OSS website coding  In Progress       mariel lopez
# FEATURE-1               OSS website design  In Progress  Tatevik Stepanyan
# STORIES:
#                                                     Summary  \
# STORY-69    Black Lives Matter Foundation charity promotion
# STORY-68  Lateral Movement: has the attacker compromised...
# STORY-67  Lateral Movement: has the attacker compromised...
# STORY-66  Update the OSS Photo Gallery and Reaction page...
# STORY-65                    ISG session content development
# STORY-64                                   Schedules Design
# STORY-63                 Homepage different sections design
# STORY-62                                   Web pages design
# STORY-61                                     Banners Design
# STORY-60                Other pages development and updates
# STORY-55     Improve/add links from HSS to OSS and opposite
# STORY-53                COVID SAFE PATHS - THREAT MODELING
# STORY-51                 Schedule mappings for the speakers
# STORY-48               Speakers Social banners and profiles
# STORY-44                    Tracks and Trainings web pages
# STORY-43                               Homepage development
# STORY-31                 Jira and Jupyter notebooks Session
# STORY-6                Security from the CEOs point of view
# STORY-1                                        Wardley Maps
#
#                             Status            Creator
# STORY-69                   Backlog  Tatevik Stepanyan
# STORY-68                   Backlog        alona reyes
# STORY-67                   Backlog        alona reyes
# STORY-66                   Backlog        alona reyes
# STORY-65                      Done        alona reyes
# STORY-64                   Backlog  Tatevik Stepanyan
# STORY-63                   Backlog  Tatevik Stepanyan
# STORY-62                   Backlog  Tatevik Stepanyan
# STORY-61                   Backlog  Tatevik Stepanyan
# STORY-60                   Backlog  Tatevik Stepanyan
# STORY-55                   Backlog  Tatevik Stepanyan
# STORY-53                   Backlog       mariel lopez
# STORY-51                   Backlog  Tatevik Stepanyan
# STORY-48                   Backlog  Tatevik Stepanyan
# STORY-44  Selected for Development  Tatevik Stepanyan
# STORY-43  Selected for Development  Tatevik Stepanyan
# STORY-31                   Backlog     Reuben Kavalov
# STORY-6                    Backlog     Reuben Kavalov
# STORY-1                    Backlog  Tatevik Stepanyan
# TASKS:
#                                                     Summary  \
# TASK-133                            Fix table-cell sessions
# TASK-132                          make all tracks colourful
# TASK-131  Provide live session information on the home p...
# TASK-130  Promotion text for Black Lives Matter Foundati...
# TASK-129                               ISG sessions briefs
# TASK-128                                   Rank The Threats
# TASK-127                        Identifying Vulnerabilities
# TASK-126                               Identifying Threats
# TASK-125  Decompose Your Application (Generate Applicati...
# TASK-124                     Profile The Application - Q1-6
# TASK-123          Identify The elements of The Threat Model
# TASK-122  If the system is to be reused in the productio...
# TASK-121  Backup all data and logs on the machine, or co...
# TASK-120  Disable or change the password of the compromi...
# TASK-119  Remove the compromised device from the network...
# TASK-118      Trigger Playbook-20 Security Incident General
# TASK-117  Perform Risk Analysis with Risk Level, Control...
# TASK-116  Identify next steps – update policies, process...
# TASK-115         Complete Incident Report/Executive Summary
# TASK-114  Create a series of diagrams and complete infog...
# TASK-113                                Root Cause Analysis
# TASK-112  Consider involving a Professional Digital Fore...
# TASK-111  Analyse acquired evidence while preserving it ...
# TASK-110  Start documentation on incident – timeline, ev...
# TASK-109  Ensure that other company assets are not prone...
# TASK-108           Notify Authorities and ICO if applicable
# TASK-107  Contact the retained third party IT company as...
# TASK-106  Depending on severity notify Executive Team an...
# TASK-105  Identify steps necessary to regain or ensure b...
# TASK-104  Identify immediate steps to prevent further ha...
# TASK-103  Determine Playbook status on Slack and activat...
# TASK-102  Start Slack Channel with Incident Name and mob...
# TASK-101            Determine incident severity (see table)
# TASK-100                               Create Jira incident
# TASK-99                           Defense SOC team playbook
# TASK-98   Exec Comms and Incident Management: Project Ma...
# TASK-97                Analyse infection points and malware
# TASK-96       Review/Investigate how the accounts were used
# TASK-95                                     Rotate AWS Keys
# TASK-94                      Reset the accounts compromised
# TASK-93                       List the accounts compromised
# TASK-92   Resume continuity for the user - reset the lap...
# TASK-91   Initiate Incident: if incident seems to be of ...
# TASK-90   Resume continuity for the user - reset the lap...
# TASK-89            Messy with the backgrounds on the header
# TASK-88   Implement Video section on Home page and as a ...
# TASK-87             Handle backgrounds in the central place
# TASK-86              Hydrate new Tracks with hugo metadata
# TASK-85   adjust hugo-generated styles to get look-n-fee...
# TASK-84   Improve Session Page for getting more particip...
# TASK-83   Make sections height aligned to the most high ...
# TASK-82   Integrate infographic-Summit will be recorded ...
# TASK-81   Integrate the Banner of "Applying OWASP Web se...
# TASK-79   In the upcoming day schedule section to put th...
# TASK-78       Add in the homepage "Happening now" reference
# TASK-76         Link from the HS sites back to the OSS site
# TASK-75          COVID SAFE PATHS session brief integration
# TASK-74                      COVID SAFE PATHS session brief
# TASK-73                       Track page Design Integration
# TASK-72   Add "Jira and Jupiter" recorded tutorials in t...
# TASK-71          Integrate "jira and Jupyter" session brief
# TASK-70   Create "Jira and Jupyter notebooks" session brief
# TASK-69   Create "Security from the CEOs point of view"s...
# TASK-68   Wardley Maps session brief integration into we...
# TASK-65                   Create Brief for Covid Safe Paths
# TASK-64                       Create brief for ISG sessions
# TASK-63    Create markup for Tracks according to new design
# TASK-62   Add Session chat to the session page "Introduc...
# TASK-61   Making it easier to create materials to share ...
# TASK-60   Implement  Training Schedule according to new ...
# TASK-59       Robert Seedorff  Social banner review/update
# TASK-58             Robert Seedorff Daily Schedule Mapping
# TASK-57           Jannik Hollenbach  Social banner creation
# TASK-56            Jannik Hollenbach Daily Schedule mapping
# TASK-55   Add links from OSS to HSS for Multijuicer intr...
# TASK-54   Remove from Photo Gallery all not up to date c...
# TASK-53                  Danny Lopez daily schedule mapping
# TASK-52   Integrate Security from the CEOs point of view...
# TASK-51   Security from the CEOs point of view session b...
# TASK-50        Add Training  Sessions to the Session Board
# TASK-49   Dynamically generate Schedule to the outstandi...
# TASK-48      Change sessions on the Homepage for second day
# TASK-47    Create a redesigned version of Session Structure
# TASK-46      Implement changes in Book your tickets section
# TASK-45   Make sure the voucher code is working and crea...
# TASK-44             Add top level YouTube link to the site
# TASK-43                  Support live streaming in homepage
# TASK-42            Add pre session videos to the home page
# TASK-41            Update Homepage to include summit times
# TASK-40                   Dinis Cruz daily schedule mapping
# TASK-39                Simon Wardley daily schedule mapping
# TASK-38                  Mario Platt daily schedule mapping
# TASK-37                 Phil Huggins Daily schedule mapping
# TASK-36             Petra Vukmirovic daily schedule mapping
# TASK-35   Create a page for speakers profiles and add  i...
# TASK-34         Add Threat Theory deck into the OSS website
# TASK-32           Add support for 'related sessions' links
# TASK-31                                  Organizers mapping
# TASK-30   Comparison of the sessions timings between the...
# TASK-29                     Add youtube icon to the footer
# TASK-27                    Create a markup of the Home page
# TASK-25   Programatically creation of speakers social "b...
# TASK-24    Link all content in OSS with content in HS (M...
# TASK-23   Session schedule for the upcoming day integrat...
# TASK-22   Integrate Social Banner for "Feedback from Pre...
# TASK-21         Link from the HS sites back to the OSS site
# TASK-20     Sponsors page design integration in the website
# TASK-19                         Homepage design integration
# TASK-16                       Add missing participant pages
# TASK-14   Clicking any "Track" user should go to schedul...
# TASK-11                       Threat Modeling Session Brief
# TASK-10                          Wardley Maps Session Brief
# TASK-9           Link all content in OSS with content in HS
# TASK-6    Threat Modeling Session update in the OSS website
# TASK-3          Move Wardley maps last year session content
#
#                             Status            Creator
# TASK-133                   Backlog     Oleg Taranenko
# TASK-132  Selected for Development     Oleg Taranenko
# TASK-131               In Progress     Oleg Taranenko
# TASK-130                   Backlog  Tatevik Stepanyan
# TASK-129                   Backlog  Tatevik Stepanyan
# TASK-128                   Backlog       mariel lopez
# TASK-127                   Backlog       mariel lopez
# TASK-126                   Backlog       mariel lopez
# TASK-125                   Backlog       mariel lopez
# TASK-124                   Backlog       mariel lopez
# TASK-123                   Backlog       mariel lopez
# TASK-122                   Backlog        alona reyes
# TASK-121                   Backlog        alona reyes
# TASK-120                   Backlog        alona reyes
# TASK-119                   Backlog        alona reyes
# TASK-118                   Backlog        alona reyes
# TASK-117                   Backlog        alona reyes
# TASK-116                   Backlog        alona reyes
# TASK-115                   Backlog        alona reyes
# TASK-114                   Backlog        alona reyes
# TASK-113                   Backlog        alona reyes
# TASK-112                   Backlog        alona reyes
# TASK-111                   Backlog        alona reyes
# TASK-110                   Backlog        alona reyes
# TASK-109                   Backlog        alona reyes
# TASK-108                   Backlog        alona reyes
# TASK-107                   Backlog        alona reyes
# TASK-106                   Backlog        alona reyes
# TASK-105                   Backlog        alona reyes
# TASK-104                   Backlog        alona reyes
# TASK-103                   Backlog        alona reyes
# TASK-102                   Backlog        alona reyes
# TASK-101                   Backlog        alona reyes
# TASK-100                   Backlog        alona reyes
# TASK-99                    Backlog        alona reyes
# TASK-98                    Backlog        alona reyes
# TASK-97                    Backlog        alona reyes
# TASK-96                    Backlog        alona reyes
# TASK-95                    Backlog        alona reyes
# TASK-94                    Backlog        alona reyes
# TASK-93                    Backlog        alona reyes
# TASK-92                    Backlog        alona reyes
# TASK-91                    Backlog        alona reyes
# TASK-90                    Backlog        alona reyes
# TASK-89                       Done     Oleg Taranenko
# TASK-88                    Backlog     Oleg Taranenko
# TASK-87                    Backlog     Oleg Taranenko
# TASK-86                       Done     Oleg Taranenko
# TASK-85                       Done     Oleg Taranenko
# TASK-84                       Done     Oleg Taranenko
# TASK-83                       Done     Oleg Taranenko
# TASK-82                    Backlog  Tatevik Stepanyan
# TASK-81                    Backlog  Tatevik Stepanyan
# TASK-79                    Backlog  Tatevik Stepanyan
# TASK-78                    Backlog  Tatevik Stepanyan
# TASK-76                    Backlog        alona reyes
# TASK-75                    Backlog  Tatevik Stepanyan
# TASK-74                    Backlog  Tatevik Stepanyan
# TASK-73                    Backlog  Tatevik Stepanyan
# TASK-72                    Backlog  Tatevik Stepanyan
# TASK-71                    Backlog  Tatevik Stepanyan
# TASK-70                    Backlog  Tatevik Stepanyan
# TASK-69                    Backlog  Tatevik Stepanyan
# TASK-68                       Done  Tatevik Stepanyan
# TASK-65                    Backlog  Tatevik Stepanyan
# TASK-64                In Progress  Tatevik Stepanyan
# TASK-63                       Done     Oleg Taranenko
# TASK-62                       Done        alona reyes
# TASK-61                    Backlog  Tatevik Stepanyan
# TASK-60                In Progress     Oleg Taranenko
# TASK-59                    Backlog  Tatevik Stepanyan
# TASK-58                       Done  Tatevik Stepanyan
# TASK-57                    Backlog  Tatevik Stepanyan
# TASK-56                    Backlog  Tatevik Stepanyan
# TASK-55                       Done  Tatevik Stepanyan
# TASK-54                    Backlog  Tatevik Stepanyan
# TASK-53                    Backlog  Tatevik Stepanyan
# TASK-52                    Backlog  Tatevik Stepanyan
# TASK-51                    Backlog  Tatevik Stepanyan
# TASK-50                    Backlog        alona reyes
# TASK-49                In Progress     Oleg Taranenko
# TASK-48                       Done     Oleg Taranenko
# TASK-47                       Done     Oleg Taranenko
# TASK-46                       Done     Oleg Taranenko
# TASK-45                    Backlog  Tatevik Stepanyan
# TASK-44                       Done  Tatevik Stepanyan
# TASK-43                    Backlog  Tatevik Stepanyan
# TASK-42                    Backlog  Tatevik Stepanyan
# TASK-41                       Done  Tatevik Stepanyan
# TASK-40                       Done  Tatevik Stepanyan
# TASK-39                       Done  Tatevik Stepanyan
# TASK-38                       Done  Tatevik Stepanyan
# TASK-37                       Done  Tatevik Stepanyan
# TASK-36                       Done  Tatevik Stepanyan
# TASK-35                       Done  Tatevik Stepanyan
# TASK-34                    Backlog  Tatevik Stepanyan
# TASK-32                    Backlog  Tatevik Stepanyan
# TASK-31                    Backlog  Tatevik Stepanyan
# TASK-30                    Backlog  Tatevik Stepanyan
# TASK-29                       Done     Oleg Taranenko
# TASK-27                       Done     Oleg Taranenko
# TASK-25                    Backlog  Tatevik Stepanyan
# TASK-24                    Backlog  Tatevik Stepanyan
# TASK-23               UNDER REVIEW  Tatevik Stepanyan
# TASK-22                    Backlog  Tatevik Stepanyan
# TASK-21                    Backlog  Tatevik Stepanyan
# TASK-20                       Done  Tatevik Stepanyan
# TASK-19                       Done  Tatevik Stepanyan
# TASK-16   Selected for Development  Tatevik Stepanyan
# TASK-14                    Backlog  Tatevik Stepanyan
# TASK-11                    Backlog  Tatevik Stepanyan
# TASK-10                       Done  Tatevik Stepanyan
# TASK-9                     Backlog  Tatevik Stepanyan
# TASK-6                     Backlog  Tatevik Stepanyan
# TASK-3                        Done        alona reyes
