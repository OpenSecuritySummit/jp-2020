# %%
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

import pandas as pd


hugo = API_Hugo_OSS()

# %%
x=hugo.df_sessions()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'organizers'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-3159131e1e0b> in <module>
# ----> 1 x=hugo.df_sessions()
#
# /codebuild/output/src291971153/src/github.com/OpenSecuritySummit/jp-2020/notebooks/api/oss_hugo/API_Hugo_OSS.py in df_sessions(self, columns, field_type)
#     117             return df[df['type']==field_type].reset_index(drop=True)
#     118
# --> 119         df['organizers'] = df['organizers'].apply(lambda x: x.split(',') if type(x) is str else x)
#     120         return df
#     121
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'organizers'

# %%
a=x[['title','when_day','when_time']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-075d848736b5> in <module>
# ----> 1 a=x[['title','when_day','when_time']]
#
# NameError: name 'x' is not defined

# %%
x.columns
# Out:
# Index(['categories', 'category', 'description', 'featured', 'host_link',
#        'host_text', 'layout', 'locked', 'organizers', 'owasp-project',
#        'participants', 'room_id', 'room_layout', 'session_slack',
#        'session_type', 'status', 'technology', 'title', 'topics', 'track',
#        'type', 'url', 'when_day', 'when_time'],
#       dtype='object')

# %%
a
# Out:
#                                                  title  \
# 0                                                 None
# 1                                               Tracks
# 2                                                  NaN
# 3                                         Wardley Maps
# 4                            Wardley Maps for Security
# 5          Using Wardley Maps and Cynefin for Security
# 6                            Using Wardley Maps on SOC
# 7    Wardley Mapping - Coordinating functions withi...
# 8                   Cell based Structures for Security
# 9                                    Mapping boot camp
# 10   Wardley Mapping - Climatic Patterns and Using ...
# 11     Introduction to Wardley Maps (Training Session)
# 12   Hand's on Wardley Maps creation (Training Sess...
# 13                                          OWASP MSTG
# 14             OWASP Mobile Security Testing Guide 101
# 15            Mobile Security Testing Guide onboarding
# 16   OWASP Mobile Security Testing Guide 101 (Sessi...
# 17   Mobile Security Testing Guide onboarding (Sess...
# 18   Creating an iOS build pipeline with security c...
# 19   Mobile Basic Security Testing and Reverse Engi...
# 20   Android and iOS Security Enhancements and Crac...
# 21         Mobile AppSec Verification Standard (MASVS)
# 22                                      OWASP HoneyPot
# 23       OWASP Application Security Curriculum Project
# 24                       ZAP working session - the HUD
# 25                    ZAP working session - automation
# 26          Application Security Verification Standard
# 27                                      OWASP Projects
# 28                                 Zap - How to use it
# 29                                 OWASP Media Project
# ..                                                 ...
# 84                      SAMM - Model discussions (Tue)
# 85                    SAMM - Parallel editing (Thu PM)
# 86                       SAMM - Parallel editing (Tue)
# 87                       SAMM - Model Challenges (Wed)
# 88               SAMM - Alignment with Threat Modeling
# 89                       SAMM - Outreach program (Mon)
# 90                                    OWASP Juice Shop
# 91                            Juice Shop Release Night
# 92                              Juice Shop Round Table
# 93                                      Juice Shop 101
# 94                   Juice Shop Contributor Onboarding
# 95                    Juice Shop Challenge Refactoring
# 96                              Juice Shop Hack'n'Code
# 97                                        Threat Model
# 98                 State and future of threat modeling
# 99                            SAMMv2 - Threat Modeling
# 100       Creating a generic diagram of a threat model
# 101                              TM track introduction
# 102  Lightweight privacy threat modeling using LIND...
# 103                        Incremental Threat Modeling
# 104                          Creating a Threat Library
# 105                                      Track closure
# 106     Automated Threat Hunting Project Collaboration
# 107  How do we persist the information from the TM ...
# 108  Lightweight privacy threat modeling using LINDDUN
# 109               Threat Model Examples Project (PM-3)
# 110               Threat Model Examples Project (PM-2)
# 111                                        TM maturity
# 112  Towards a unified way of describing threat models
# 113                            Lessons from the Legion
#
#                     when_day                             when_time
# 0                       None                                  None
# 1                        NaN                                   NaN
# 2                        NaN                                   NaN
# 3                Mon,Tue,Wed                                   NaN
# 4                        Wed                                  PM-2
# 5                        Wed                                  PM-2
# 6                        Wed                                  PM-3
# 7                        Thu                                  PM-3
# 8                        Thu                                  PM-1
# 9                        Thu                                  AM-1
# 10                       Thu                                  PM-2
# 11                       Mon                                  PM-1
# 12                       Mon                                  PM-3
# 13   Mon, Tue, Wed, Thu, Fri                                  None
# 14                       Mon                                  PM-1
# 15                       Mon                                  PM-1
# 16                       Wed                                  AM-1
# 17                       Wed                                  AM-1
# 18                       Wed                                  AM-1
# 19           Mon,Tue,Wed,Thu  AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 20       Mon,Tue,Wed,Thu,Fri  AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 21                       Mon         AM-1, DS-2, PM-1, PM-2, Eve-1
# 22                       Wed                                  PM-2
# 23                       Tue                                  AM-1
# 24                       Tue                                  PM-1
# 25                       Tue                                  AM-1
# 26                       Wed                                  PM-1
# 27               Mon,Wed,Fri                                   NaN
# 28                       Tue                                 Eve-1
# 29                  Tue, Wed                                 Eve-1
# ..                       ...                                   ...
# 84                       Tue                                  PM-2
# 85                       Thu                                  PM-1
# 86                       Tue                                  PM-1
# 87                       Wed                                  EV-1
# 88                       Thu                                  PM-2
# 89                       Mon                                  DS-2
# 90           Mon,Tue,Wed,Thu                                   NaN
# 91                       Thu                          Eve-1, Eve-2
# 92                       Thu                                  PM-2
# 93                       Tue                                  AM-1
# 94                       Tue                                  PM-1
# 95                       Thu                                  AM-1
# 96               Mon,Tue,Wed                          Eve-1, Eve-2
# 97                   Wed,Thu                                   NaN
# 98                       Wed                                  AM-1
# 99                       Thu                                  PM-3
# 100                      Tue                                  PM-1
# 101                      Mon                                  PM-1
# 102                      Mon                                  PM-3
# 103                      Thu                                  PM-1
# 104                     None                                  None
# 105                      Thu                                  PM-2
# 106                      Wed                                  PM-2
# 107                      Tue                                  AM-1
# 108                      Mon                                  PM-2
# 109                      Tue                                  PM-3
# 110                      Wed                                  PM-3
# 111                      Tue                                  PM-2
# 112                      Thu                                  AM-1
# 113                      Mon                                  DS-2
#
# [114 rows x 3 columns]

# %%
x=hugo.sessions_oss()

# %%
x
# Out:
# {'/codebuild/output/src212871611/src/github.com/OpenSecuritySummit/jp-tests/notebooks/oss2019/content/tracks/_template.md': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60de2e8>,
#  'Tracks': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60dcef0>,
#  '/codebuild/output/src212871611/src/github.com/OpenSecuritySummit/jp-tests/notebooks/oss2019/content/tracks/json.md': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e1320>,
#  'Wardley Maps': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60dccc0>,
#  'Wardley Maps for Security': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60de278>,
#  'Using Wardley Maps and Cynefin for Security': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60dc128>,
#  'Using Wardley Maps on SOC': <oss_hugo.OSS_Session.OSS_Session at 0x7f026f1e0cc0>,
#  'Wardley Mapping - Coordinating functions within a PST organisation': <oss_hugo.OSS_Session.OSS_Session at 0x7f02acf2c240>,
#  'Cell based Structures for Security': <oss_hugo.OSS_Session.OSS_Session at 0x7f02ad0137b8>,
#  'Mapping boot camp': <oss_hugo.OSS_Session.OSS_Session at 0x7f02ad013a20>,
#  'Wardley Mapping - Climatic Patterns and Using Doctrine': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b612da58>,
#  'Introduction to Wardley Maps (Training Session)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60da978>,
#  "Hand's on Wardley Maps creation (Training Session)": <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60de438>,
#  'OWASP MSTG': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61ae080>,
#  'OWASP Mobile Security Testing Guide 101': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61aea58>,
#  'Mobile Security Testing Guide onboarding': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61ae470>,
#  'OWASP Mobile Security Testing Guide 101 (Session 2)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60da748>,
#  'Mobile Security Testing Guide onboarding (Session 2)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60deef0>,
#  'Creating an iOS build pipeline with security checks': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60de710>,
#  'Mobile Basic Security Testing and Reverse Engineering': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60de208>,
#  'Android and iOS Security Enhancements and Crackme Apps': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60dcb70>,
#  'Mobile AppSec Verification Standard (MASVS)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60dc400>,
#  'OWASP HoneyPot': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6176f28>,
#  'OWASP Application Security Curriculum Project': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61e7dd8>,
#  'ZAP working session - the HUD': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61f0ba8>,
#  'ZAP working session - automation': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61f0c50>,
#  'Application Security Verification Standard': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b612db00>,
#  'OWASP Projects': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b612db70>,
#  'Zap - How to use it': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61e7828>,
#  'OWASP Media Project': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61e77f0>,
#  'ZAP working session - future plans': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6176400>,
#  "Security Challenges - Collate others' strategies and assumptions": <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6184240>,
#  'Customising the Chaos Engineering Toolkit': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b617bbe0>,
#  'Security Challenges - An Introduction': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b617b160>,
#  'Cyber Risk Modeling': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b617b0b8>,
#  'OWASP community-docs': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61769e8>,
#  'Real world Chaos Engineering': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61768d0>,
#  'Third Party Due Diligence': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6176668>,
#  'Using graphs for GDPR mappings and visualisations': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60dab00>,
#  'Ask me anything (AMA) on GDPR': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60da4a8>,
#  'Misc': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61806d8>,
#  'Security Challenges - Next step': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6180048>,
#  'Security Challenges - Analysis, Analogies': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61f1748>,
#  "Securing Kubernete's hosted APIs": <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6184f28>,
#  'Scaling API Security': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6184a58>,
#  'Introduction to Cynefin Framework (Training Session)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6184f98>,
#  'Security Challenges - Analyse others': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6185f98>,
#  'Using Cynefin Framework making strategic security decisions': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6185eb8>,
#  'DevSecOps': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6198f60>,
#  'WAFs - Understanding and measuring how they behave': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e1cf8>,
#  'Writing security tests to confirm vulnerabilities and fixes': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6190048>,
#  'Creating Appsec metrics and visualisation': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699fb400>,
#  'Integrating Security Tools in the SDL': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699fb208>,
#  'DevSecOps Maturity Model (DSOMM)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61aa0f0>,
#  'Creating a Security Champions network': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b618bd68>,
#  'From Threat Modeling to DevSecOps metrics': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b618bcc0>,
#  'Securing the CI Pipeline': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61908d0>,
#  'Dealing with DevSecOps Findings': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6190320>,
#  'Secrets Management': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b619ec18>,
#  'Agile Practices for Security Teams': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b619eb00>,
#  'OWASP SAMM': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b6198400>,
#  'SAMM user session - Introduction': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61982e8>,
#  'SAMM track - Onboarding': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e1358>,
#  'SAMM user session - Round-table': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e1b00>,
#  'SAMM - Outreach program (Tue)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e34e0>,
#  'Mapping OWASP DevSecOps Maturity Model to SAMMv2': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e3da0>,
#  'SAMM - Measurement model (Mon EV)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e5470>,
#  'SAMM - Alignment with other OWASP projects (Wed)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b60e5dd8>,
#  'SAMM - Measurement model (Mon PM)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61a1668>,
#  'SAMM - Alignment with other OWASP projects (Thu)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02b61a13c8>,
#  'SAMM - Parallel editing (Thu AM)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699df9e8>,
#  'SAMM - Agile guidance': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699d9860>,
#  'SAMM - SAMM benchmarking': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699d9e80>,
#  'SAMM - Parallel editing (Wed PM)': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269a04fd0>,
#  'SAMM - Planning and Roadmap': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269a04198>,
#  'SAMM - Model discussions (Wed)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e2588>,
#  'SAMM - Editing agreements and parallel editing': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e2e80>,
#  'SAMM - Alignment with other OWASP projects (Fri)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e2ba8>,
#  'SAMM - Any Other Business': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699dfcc0>,
#  'SAMM - Outreach wrap-up': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699dff60>,
#  'SAMM - SAMM documents and parallel editing (Wed AM)': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997b668>,
#  'SAMM - DevOps guidance': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e7dd8>,
#  'SAMM - Tooling': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997d5c0>,
#  'SAMM - Model Challenges (Tue)': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997b518>,
#  'SAMM - Model discussions (Tue)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e7668>,
#  'SAMM - Parallel editing (Thu PM)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e7cc0>,
#  'SAMM - Parallel editing (Tue)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699e7630>,
#  'SAMM - Model Challenges (Wed)': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997dcf8>,
#  'SAMM - Alignment with Threat Modeling': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699816d8>,
#  'SAMM - Outreach program (Mon)': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997b240>,
#  'OWASP Juice Shop': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997d9b0>,
#  'Juice Shop Release Night': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269981240>,
#  'Juice Shop Round Table': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997bcf8>,
#  'Juice Shop 101': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997bdd8>,
#  'Juice Shop Contributor Onboarding': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997bd30>,
#  'Juice Shop Challenge Refactoring': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997b3c8>,
#  "Juice Shop Hack'n'Code": <oss_hugo.OSS_Session.OSS_Session at 0x7f0269981828>,
#  'Threat Model': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699864a8>,
#  'State and future of threat modeling': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997d358>,
#  'SAMMv2 - Threat Modeling': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997db00>,
#  'Creating a generic diagram of a threat model': <oss_hugo.OSS_Session.OSS_Session at 0x7f026997d7b8>,
#  'TM track introduction': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269981b38>,
#  'Lightweight privacy threat modeling using LINDDUN Part II': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269986d68>,
#  'Incremental Threat Modeling': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269989ac8>,
#  'Creating a Threat Library': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269981cc0>,
#  'Track closure': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269981780>,
#  'Automated Threat Hunting Project Collaboration': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269981160>,
#  'How do we persist the information from the TM Slack channel?': <oss_hugo.OSS_Session.OSS_Session at 0x7f026998f128>,
#  'Lightweight privacy threat modeling using LINDDUN': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699893c8>,
#  'Threat Model Examples Project (PM-3)': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699866a0>,
#  'Threat Model Examples Project (PM-2)': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269986668>,
#  'TM maturity': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269986160>,
#  'Towards a unified way of describing threat models': <oss_hugo.OSS_Session.OSS_Session at 0x7f0269989a20>,
#  'Lessons from the Legion': <oss_hugo.OSS_Session.OSS_Session at 0x7f02699912b0>}

# %%
a[a['title']=='Threat Modeling Introduction']
# Out:
# Empty DataFrame
# Columns: [title, when_day, when_time]
# Index: []
