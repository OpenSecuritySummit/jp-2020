# %%
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

import pandas as pd


hugo = API_Hugo_OSS()

# %%
x=hugo.df_sessions() # the .head(20) command will show the top 20

# %%
a=x[['title','when_day','when_time']]

# %%
x.columns
# Out:
# Index(['categories', 'category', 'description', 'featured', 'host_link',
#        'host_text', 'layout', 'locked', 'organizers', 'owasp-project',
#        'participants', 'room_id', 'room_layout', 'session_slack',
#        'session_type', 'status', 'technology', 'title', 'topics', 'track',
#        'type', 'url', 'when_day', 'when_time'],
#       dtype='object')

# %%
x[5:]
# Out:
#                                     categories category  \
# 5                                          NaN      NaN
# 6                                          NaN      NaN
# 7                                          NaN      NaN
# 8                                       [CISO]      NaN
# 9                                          NaN      NaN
# 10                                         NaN      NaN
# 11                                         NaN      NaN
# 12                                         NaN      NaN
# 13                                         NaN      NaN
# 14                                         NaN      NaN
# 15                                         NaN      NaN
# 16                                         NaN      NaN
# 17                                         NaN      NaN
# 18                                        MSTG      NaN
# 19                                        MSTG      NaN
# 20                                        MSTG      NaN
# 21                                        MSTG      NaN
# 22                                         NaN      NaN
# 23                                 [Education]      NaN
# 24                                       [ZAP]      NaN
# 25                                       [ZAP]      NaN
# 26                                         NaN      NaN
# 27                                         NaN      NaN
# 28                                       [ZAP]      NaN
# 29                                        None      NaN
# 30                                       [ZAP]      NaN
# 31                      [Strategic Challenges]      NaN
# 32                              [API Security]      NaN
# 33   [Strategic Challenges, Strategy overview]      NaN
# 34                                [CISO, RISK]      NaN
# ..                                         ...      ...
# 84                                        None      NaN
# 85                                        None      NaN
# 86                                        None      NaN
# 87                                        None      NaN
# 88                                        None      NaN
# 89                                        None      NaN
# 90                                         NaN      NaN
# 91                                         NaN      NaN
# 92                                         NaN      NaN
# 93                                         NaN      NaN
# 94                                         NaN      NaN
# 95                                         NaN      NaN
# 96                                         NaN      NaN
# 97                                         NaN      NaN
# 98                                        None      NaN
# 99                                        None      NaN
# 100                                      graph      NaN
# 101                                       None      NaN
# 102                                       None      NaN
# 103                                       None      NaN
# 104                                       None      NaN
# 105                                       None      NaN
# 106                                       None      NaN
# 107                                       None      NaN
# 108                                       None      NaN
# 109                                        NaN      NaN
# 110                                        NaN      NaN
# 111                                       None      NaN
# 112                                       None      NaN
# 113                                        NaN      NaN
#
#                                            description featured  host_link  \
# 5    session on the intersection of Wardley Maps an...     True        NaN
# 6                                                 None     True        NaN
# 7     Coordinating functions within a PST organisation     True        NaN
# 8    Cell based Structures for Security - Small aut...     True        NaN
# 9    Wardely Mapping boot camp - Zero to Mapping He...     True        NaN
# 10   Wardley Mapping, Understanding Climatic Patter...     True        NaN
# 11        New to Wardley maps? This session is for you     None        NaN
# 12   Want to have a go at creating your own Wardley...     None        NaN
# 13        Sessions focusing on the OWASP MSTG project.     True        NaN
# 14   MSTG introduction for newbies (Two sessions av...     None        NaN
# 15   MSTG introduction for new contributors (Two se...     True        NaN
# 16   MSTG introduction for newbies (Two sessions av...     None        NaN
# 17   MSTG introduction for new contributors (Two se...     True        NaN
# 18   Brainstorming for a iOS pipeline with security...     True        NaN
# 19   Work on the Mobile Basic Security Testing and ...     None        NaN
# 20                    Updating the content of the MSTG     True        NaN
# 21                Work on the open issues of the MASVS     True        NaN
# 22                           Session on OWASP Honeypot    False        NaN
# 23   Kick-off session for the new AppSec Curriculum...     True        NaN
# 24                      Working session on the ZAP HUD     True        NaN
# 25                   Working session on ZAP automation     True        NaN
# 26                                     Session on ASVS     True        NaN
# 27                 Sessions on multiple OWASP Projects     True        NaN
# 28                      User session to help ZAP users     True        NaN
# 29   Update project docs and plan the next phase of...      NaN        NaN
# 30                Working sessions on ZAP future plans     True        NaN
# 31                     Collate results from Wednesday.     None        NaN
# 32   Practical Guide to Extending the Chaos Toolkit...     None        NaN
# 33                           Introduction and overview     None        NaN
# 34                            Session on Risk Modeling     True        NaN
# ..                                                 ...      ...        ...
# 84   Parallel editing session to improve the conten...     None        NaN
# 85   Discussion on the different SAMM documents and...     None        NaN
# 86   Parallel editing session to improve the conten...     None        NaN
# 87             Discussing outstanding model challenges     None        NaN
# 88   Aligning the SAMM model with the Threat Modeli...     None        NaN
# 89   Discussing the outreach for the OWASP SAMM pro...     None        NaN
# 90               Sessions focusing on OWASP Juice Shop     True        NaN
# 91             Go-live of new OWASP Juice Shop release    False        NaN
# 92               Round table of OWASP Juice Shop users     True        NaN
# 93           OWASP Juice Shop introduction for newbies     True        NaN
# 94   OWASP Juice Shop introduction for new contribu...     True        NaN
# 95   Refactoring the categories and difficulty rati...     True        NaN
# 96      Coding for and hacking of the OWASP Juice Shop     True        NaN
# 97                Sessions focusing on Threat Modeling     True        NaN
# 98   What is the current state of TM and where do w...     True        NaN
# 99   Discuss the SAMM threat modeling practice toge...     None        NaN
# 100       Creating a generic diagram of a threat model     True        NaN
# 101  Introduction of the TM track and way of workin...     True        NaN
# 102  Lightweight privacy threat modeling using LIND...     True        NaN
# 103                       How to scale Threat Modeling     True        NaN
# 104                     Threat Library Working Session     None        NaN
# 105                                      Track closure     True        NaN
# 106  Discuss the OWASP Automated Threat Hunting Pro...     None        NaN
# 107  How do we persist the information from the TM ...     None        NaN
# 108  Lightweight privacy threat modeling using LINDDUN     True        NaN
# 109  Kick off of the OWASP Threat Model Examples Pr...     None        NaN
# 110                          Let's get some work done!     None        NaN
# 111               How do we measure the maturity of TM     True        NaN
# 112  A presentation and discussion of a new languag...     True        NaN
# 113  Sessions focusing on the strategic challenges ...     True        NaN
#
#      host_text layout locked  \
# 5          NaN    NaN   True
# 6          NaN    NaN   True
# 7          NaN    NaN   True
# 8          NaN    NaN   True
# 9          NaN    NaN   True
# 10         NaN    NaN   True
# 11         NaN    NaN    NaN
# 12         NaN    NaN    NaN
# 13         NaN    NaN    NaN
# 14         NaN    NaN    NaN
# 15         NaN    NaN    NaN
# 16         NaN    NaN    NaN
# 17         NaN    NaN    NaN
# 18         NaN    NaN    NaN
# 19         NaN    NaN    NaN
# 20         NaN    NaN    NaN
# 21         NaN    NaN    NaN
# 22         NaN    NaN    NaN
# 23         NaN    NaN    NaN
# 24         NaN    NaN   True
# 25         NaN    NaN   True
# 26         NaN    NaN    NaN
# 27         NaN    NaN    NaN
# 28         NaN    NaN    NaN
# 29         NaN    NaN    NaN
# 30         NaN    NaN   True
# 31         NaN    NaN    NaN
# 32         NaN    NaN  False
# 33         NaN    NaN    NaN
# 34         NaN    NaN    NaN
# ..         ...    ...    ...
# 84         NaN    NaN   True
# 85         NaN    NaN   True
# 86         NaN    NaN   True
# 87         NaN    NaN   True
# 88         NaN    NaN   True
# 89         NaN    NaN   True
# 90         NaN    NaN    NaN
# 91         NaN    NaN    NaN
# 92         NaN    NaN    NaN
# 93         NaN    NaN    NaN
# 94         NaN    NaN    NaN
# 95         NaN    NaN    NaN
# 96         NaN    NaN    NaN
# 97         NaN    NaN    NaN
# 98         NaN    NaN   True
# 99         NaN    NaN   True
# 100        NaN    NaN   True
# 101        NaN    NaN   True
# 102        NaN    NaN   True
# 103        NaN    NaN   True
# 104        NaN    NaN    NaN
# 105        NaN    NaN   True
# 106        NaN    NaN  False
# 107        NaN    NaN   True
# 108        NaN    NaN   True
# 109        NaN    NaN    NaN
# 110        NaN    NaN    NaN
# 111        NaN    NaN   True
# 112        NaN    NaN   True
# 113        NaN    NaN    NaN
#
#                                             organizers owasp-project  ...  \
# 5                        [Simon Wardley, Dave Snowden]           NaN  ...
# 6                                      [Tony Richards]           NaN  ...
# 7                                      [Simon Wardley]           NaN  ...
# 8                       [Tony Richards, Simon Wardley]           NaN  ...
# 9                                      [Simon Wardley]           NaN  ...
# 10                                     [Simon Wardley]           NaN  ...
# 11                                     [Tony Richards]           NaN  ...
# 12                                     [Tony Richards]           NaN  ...
# 13   [Jeroen Willemsen, Carlos Holguera, Sven Schle...           NaN  ...
# 14                                  [Jeroen Willemsen]           NaN  ...
# 15                                  [Jeroen Willemsen]           NaN  ...
# 16                                  [Jeroen Willemsen]           NaN  ...
# 17                                  [Jeroen Willemsen]           NaN  ...
# 18                                     [Sven Schleier]           NaN  ...
# 19                                   [Carlos Holguera]           NaN  ...
# 20                                     [Sven Schleier]           NaN  ...
# 21                                    [Jeroen Beckers]           NaN  ...
# 22                  [Felipe Zipitria, Adrian Winckles]           NaN  ...
# 23                       [Adrian Winckles, John DiLeo]           NaN  ...
# 24                                    [Simon Bennetts]           NaN  ...
# 25                                    [Simon Bennetts]           NaN  ...
# 26                                        [Jim Manico]           NaN  ...
# 27                                                None         False  ...
# 28                                                None          True  ...
# 29                                   [Jonathan Marcil]           NaN  ...
# 30                                    [Simon Bennetts]           NaN  ...
# 31                                        [Nick Drage]           NaN  ...
# 32                             [(one of participants)]           NaN  ...
# 33                                        [Nick Drage]           NaN  ...
# 34                                      [Phil Huggins]           NaN  ...
# ..                                                 ...           ...  ...
# 84               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 85               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 86               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 87               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 88               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 89               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 90                                  [Bjoern Kimminich]          True  ...
# 91                                  [Bjoern Kimminich]           NaN  ...
# 92                                  [Bjoern Kimminich]           NaN  ...
# 93                                  [Bjoern Kimminich]           NaN  ...
# 94                                  [Bjoern Kimminich]           NaN  ...
# 95                                  [Bjoern Kimminich]           NaN  ...
# 96                                  [Bjoern Kimminich]           NaN  ...
# 97                                                None         False  ...
# 98                                    [Steven Wierckx]           NaN  ...
# 99            [Steven Wierckx, Sebastien Deleersnyder]           NaN  ...
# 100                                   [Steven Wierckx]           NaN  ...
# 101                                   [Steven Wierckx]           NaN  ...
# 102                        [Steven Wierckx, Kim Wuyts]           NaN  ...
# 103                    [Irene Michlin, Steven Wierckx]           NaN  ...
# 104                              [Steven van der Baan]           NaN  ...
# 105                                   [Steven Wierckx]           NaN  ...
# 106                      [Steven Wierckx, Tash Norris]           NaN  ...
# 107                                   [Steven Wierckx]           NaN  ...
# 108                        [Steven Wierckx, Kim Wuyts]           NaN  ...
# 109                     [Jonathan Marcil, Tash Norris]           NaN  ...
# 110                     [Jonathan Marcil, Tash Norris]           NaN  ...
# 111                                   [Steven Wierckx]           NaN  ...
# 112                                   [Steven Wierckx]           NaN  ...
# 113                                       [Nick Drage]           NaN  ...
#
#     session_type          status            technology  \
# 5            NaN           draft                  None
# 6            NaN  review-content                  None
# 7            NaN    need-content                  None
# 8            NaN            done                   NaN
# 9            NaN    need-content                  None
# 10           NaN    need-content                  None
# 11           NaN            done                  None
# 12           NaN            done                  None
# 13           NaN  review-content                Mobile
# 14           NaN  review-content                  None
# 15           NaN  review-content                  None
# 16           NaN  review-content                  None
# 17           NaN  review-content                  None
# 18           NaN  review-content           Mobile, iOS
# 19           NaN  review-content  Mobile, iOS, Android
# 20           NaN  review-content  Mobile, iOS, Android
# 21           NaN  review-content  Mobile, iOS, Android
# 22           NaN  review-content                   NaN
# 23           NaN  review-content                  None
# 24           NaN  review-content                  None
# 25           NaN  review-content                  None
# 26           NaN  review-content                   NaN
# 27           NaN             NaN                   NaN
# 28           NaN           draft                   NaN
# 29           NaN           draft                  None
# 30           NaN  review-content                  None
# 31           NaN           draft                  None
# 32           NaN  review-content                  None
# 33           NaN           draft                  None
# 34           NaN           draft                   NaN
# ..           ...             ...                   ...
# 84           NaN  review-content                  None
# 85           NaN  review-content                  None
# 86           NaN  review-content                  None
# 87           NaN  review-content                  None
# 88           NaN  review-content                  None
# 89           NaN  review-content                  None
# 90           NaN             NaN                   NaN
# 91           NaN  review-content                  None
# 92           NaN  review-content                  None
# 93           NaN  review-content                  None
# 94           NaN  review-content                  None
# 95           NaN  review-content                  None
# 96           NaN  review-content                  None
# 97           NaN             NaN                   NaN
# 98           NaN  review-content                  None
# 99           NaN  review-content                  None
# 100          NaN  review-content                  None
# 101          NaN  review-content                  None
# 102          NaN  review-content                  None
# 103          NaN  review-content                  None
# 104          NaN           draft          Threat Model
# 105          NaN            done                  None
# 106          NaN            done                  None
# 107          NaN  review-content                  None
# 108          NaN  review-content                  None
# 109          NaN            done         pytm,plantuml
# 110          NaN            done         pytm,plantuml
# 111          NaN  review-content                  None
# 112          NaN            done                  None
# 113          NaN             NaN                   NaN
#
#                                                  title  \
# 5          Using Wardley Maps and Cynefin for Security
# 6                            Using Wardley Maps on SOC
# 7    Wardley Mapping - Coordinating functions withi...
# 8                   Cell based Structures for Security
# 9                                    Mapping boot camp
# 10   Wardley Mapping - Climatic Patterns and Using ...
# 11     Introduction to Wardley Maps (Training Session)
# 12   Hand's on Wardley Maps creation (Training Sess...
# 13                                          OWASP MSTG
# 14             OWASP Mobile Security Testing Guide 101
# 15            Mobile Security Testing Guide onboarding
# 16   OWASP Mobile Security Testing Guide 101 (Sessi...
# 17   Mobile Security Testing Guide onboarding (Sess...
# 18   Creating an iOS build pipeline with security c...
# 19   Mobile Basic Security Testing and Reverse Engi...
# 20   Android and iOS Security Enhancements and Crac...
# 21         Mobile AppSec Verification Standard (MASVS)
# 22                                      OWASP HoneyPot
# 23       OWASP Application Security Curriculum Project
# 24                       ZAP working session - the HUD
# 25                    ZAP working session - automation
# 26          Application Security Verification Standard
# 27                                      OWASP Projects
# 28                                 Zap - How to use it
# 29                                 OWASP Media Project
# 30                  ZAP working session - future plans
# 31   Security Challenges - Collate others' strategi...
# 32           Customising the Chaos Engineering Toolkit
# 33               Security Challenges - An Introduction
# 34                                 Cyber Risk Modeling
# ..                                                 ...
# 84                      SAMM - Model discussions (Tue)
# 85                    SAMM - Parallel editing (Thu PM)
# 86                       SAMM - Parallel editing (Tue)
# 87                       SAMM - Model Challenges (Wed)
# 88               SAMM - Alignment with Threat Modeling
# 89                       SAMM - Outreach program (Mon)
# 90                                    OWASP Juice Shop
# 91                            Juice Shop Release Night
# 92                              Juice Shop Round Table
# 93                                      Juice Shop 101
# 94                   Juice Shop Contributor Onboarding
# 95                    Juice Shop Challenge Refactoring
# 96                              Juice Shop Hack'n'Code
# 97                                        Threat Model
# 98                 State and future of threat modeling
# 99                            SAMMv2 - Threat Modeling
# 100       Creating a generic diagram of a threat model
# 101                              TM track introduction
# 102  Lightweight privacy threat modeling using LIND...
# 103                        Incremental Threat Modeling
# 104                          Creating a Threat Library
# 105                                      Track closure
# 106     Automated Threat Hunting Project Collaboration
# 107  How do we persist the information from the TM ...
# 108  Lightweight privacy threat modeling using LINDDUN
# 109               Threat Model Examples Project (PM-3)
# 110               Threat Model Examples Project (PM-2)
# 111                                        TM maturity
# 112  Towards a unified way of describing threat models
# 113                            Lessons from the Legion
#
#                                                 topics             track  \
# 5                                                 None      Wardley Maps
# 6                                                 None      Wardley Maps
# 7                                                 None      Wardley Maps
# 8                                       [Wardley Maps]      Wardley Maps
# 9                                                 None      Wardley Maps
# 10                                                None      Wardley Maps
# 11                                                None      Wardley Maps
# 12                                                None      Wardley Maps
# 13                                     Mobile Security               NaN
# 14                                                None        OWASP MSTG
# 15                                                None        OWASP MSTG
# 16                                                None        OWASP MSTG
# 17                                                None        OWASP MSTG
# 18                                                 NaN        OWASP MSTG
# 19                                                 NaN        OWASP MSTG
# 20                                                 NaN        OWASP MSTG
# 21                                                 NaN        OWASP MSTG
# 22                                     [Owasp Project]    OWASP Projects
# 23   [Owasp Project, OWASP Application Security Cur...    OWASP Projects
# 24                                                 NaN    OWASP Projects
# 25                                                 NaN    OWASP Projects
# 26                                     [Owasp Project]    OWASP Projects
# 27                                                 NaN               NaN
# 28                                                 NaN    OWASP Projects
# 29                                                 NaN    OWASP Projects
# 30                                                 NaN    OWASP Projects
# 31                                                 NaN              Misc
# 32                                                 NaN              Misc
# 33                                                 NaN              Misc
# 34                                                 NaN              Misc
# ..                                                 ...               ...
# 84                                                 NaN        OWASP SAMM
# 85                                                 NaN        OWASP SAMM
# 86                                                 NaN        OWASP SAMM
# 87                                                 NaN        OWASP SAMM
# 88                                                 NaN        OWASP SAMM
# 89                                                 NaN        OWASP SAMM
# 90                                                 NaN               NaN
# 91                                                None  OWASP Juice Shop
# 92                                                None  OWASP Juice Shop
# 93                                                None  OWASP Juice Shop
# 94                                                None  OWASP Juice Shop
# 95                                                None  OWASP Juice Shop
# 96                                                None  OWASP Juice Shop
# 97                                                 NaN               NaN
# 98                                                None      Threat Model
# 99                                                 NaN      Threat Model
# 100                                               None      Threat Model
# 101                                               None      Threat Model
# 102                                               None      Threat Model
# 103                                                NaN      Threat Model
# 104                                                NaN               NaN
# 105                                               None      Threat Model
# 106                                                NaN      Threat Model
# 107                                               None      Threat Model
# 108                                               None      Threat Model
# 109                                               None      Threat Model
# 110                                               None      Threat Model
# 111                                               None      Threat Model
# 112                                               None      Threat Model
# 113                                                NaN               NaN
#
#                 type  url                 when_day  \
# 5       user-session  NaN                      Wed
# 6       user-session  NaN                      Wed
# 7    working-session  NaN                      Thu
# 8    working-session  NaN                      Thu
# 9    working-session  NaN                      Thu
# 10   working-session  NaN                      Thu
# 11   working-session  NaN                      Mon
# 12   working-session  NaN                      Mon
# 13             track  NaN  Mon, Tue, Wed, Thu, Fri
# 14      user-session  NaN                      Mon
# 15      user-session  NaN                      Mon
# 16      user-session  NaN                      Wed
# 17      user-session  NaN                      Wed
# 18   working-session  NaN                      Wed
# 19   working-session  NaN          Mon,Tue,Wed,Thu
# 20   working-session  NaN      Mon,Tue,Wed,Thu,Fri
# 21   working-session  NaN                      Mon
# 22   working-session  NaN                      Wed
# 23   working-session  NaN                      Tue
# 24   working-session  NaN                      Tue
# 25   working-session  NaN                      Tue
# 26   working-session  NaN                      Wed
# 27             track  NaN              Mon,Wed,Fri
# 28      user-session  NaN                      Tue
# 29   working-session  NaN                 Tue, Wed
# 30   working-session  NaN                      Wed
# 31   working-session  NaN                      Thu
# 32   working-session  NaN                      Fri
# 33   working-session  NaN                      Mon
# 34   working-session  NaN                      Thu
# ..               ...  ...                      ...
# 84   working-session  NaN                      Tue
# 85   working-session  NaN                      Thu
# 86   working-session  NaN                      Tue
# 87   working-session  NaN                      Wed
# 88   working-session  NaN                      Thu
# 89   working-session  NaN                      Mon
# 90             track  NaN          Mon,Tue,Wed,Thu
# 91      user-session  NaN                      Thu
# 92      user-session  NaN                      Thu
# 93      user-session  NaN                      Tue
# 94      user-session  NaN                      Tue
# 95   working-session  NaN                      Thu
# 96   working-session  NaN              Mon,Tue,Wed
# 97             track  NaN                  Wed,Thu
# 98   working-session  NaN                      Wed
# 99   working-session  NaN                      Thu
# 100  working-session  NaN                      Tue
# 101  working-session  NaN                      Mon
# 102  working-session  NaN                      Mon
# 103  working-session  NaN                      Thu
# 104  working-session  NaN                     None
# 105  working-session  NaN                      Thu
# 106  working-session  NaN                      Wed
# 107  working-session  NaN                      Tue
# 108  working-session  NaN                      Mon
# 109  working-session  NaN                      Tue
# 110  working-session  NaN                      Wed
# 111  working-session  NaN                      Tue
# 112  working-session  NaN                      Thu
# 113          keynote  NaN                      Mon
#
#                                 when_time
# 5                                    PM-2
# 6                                    PM-3
# 7                                    PM-3
# 8                                    PM-1
# 9                                    AM-1
# 10                                   PM-2
# 11                                   PM-1
# 12                                   PM-3
# 13                                   None
# 14                                   PM-1
# 15                                   PM-1
# 16                                   AM-1
# 17                                   AM-1
# 18                                   AM-1
# 19   AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 20   AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 21          AM-1, DS-2, PM-1, PM-2, Eve-1
# 22                                   PM-2
# 23                                   AM-1
# 24                                   PM-1
# 25                                   AM-1
# 26                                   PM-1
# 27                                    NaN
# 28                                  Eve-1
# 29                                  Eve-1
# 30                                   AM-1
# 31                                   PM-1
# 32                                   PM-1
# 33                                   PM-1
# 34                                   PM-3
# ..                                    ...
# 84                                   PM-2
# 85                                   PM-1
# 86                                   PM-1
# 87                                   EV-1
# 88                                   PM-2
# 89                                   DS-2
# 90                                    NaN
# 91                           Eve-1, Eve-2
# 92                                   PM-2
# 93                                   AM-1
# 94                                   PM-1
# 95                                   AM-1
# 96                           Eve-1, Eve-2
# 97                                    NaN
# 98                                   AM-1
# 99                                   PM-3
# 100                                  PM-1
# 101                                  PM-1
# 102                                  PM-3
# 103                                  PM-1
# 104                                  None
# 105                                  PM-2
# 106                                  PM-2
# 107                                  AM-1
# 108                                  PM-2
# 109                                  PM-3
# 110                                  PM-3
# 111                                  PM-2
# 112                                  AM-1
# 113                                  DS-2
#
# [109 rows x 24 columns]

# %%
a[a['title']=='Threat Modeling Introduction']
# Out:
# Empty DataFrame
# Columns: [title, when_day, when_time]
# Index: []
