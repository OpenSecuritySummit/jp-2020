# %%
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

import pandas as pd


hugo = API_Hugo_OSS()

# %%
x=hugo.df_sessions() # the .head(20) command will show the top 20

# %%
x
# Out:
#       categories category                                        description  \
# 0            NaN      NaN                                               None
# 1            NaN      NaN                                                NaN
# 2            NaN      NaN                                                NaN
# 3            NaN      NaN  Sessions focusing on the use of Wardley Maps i...
# 4           None      NaN  Practical session on using Wardley Maps for Se...
# 5            NaN      NaN  session on the intersection of Wardley Maps an...
# 6            NaN      NaN                                               None
# 7            NaN      NaN   Coordinating functions within a PST organisation
# 8         [CISO]      NaN  Cell based Structures for Security - Small aut...
# 9            NaN      NaN  Wardely Mapping boot camp - Zero to Mapping He...
# 10           NaN      NaN  Wardley Mapping, Understanding Climatic Patter...
# 11           NaN      NaN       New to Wardley maps? This session is for you
# 12           NaN      NaN  Want to have a go at creating your own Wardley...
# 13           NaN      NaN       Sessions focusing on the OWASP MSTG project.
# 14           NaN      NaN  MSTG introduction for newbies (Two sessions av...
# 15           NaN      NaN  MSTG introduction for new contributors (Two se...
# 16           NaN      NaN  MSTG introduction for newbies (Two sessions av...
# 17           NaN      NaN  MSTG introduction for new contributors (Two se...
# 18          MSTG      NaN  Brainstorming for a iOS pipeline with security...
# 19          MSTG      NaN  Work on the Mobile Basic Security Testing and ...
# 20          MSTG      NaN                   Updating the content of the MSTG
# 21          MSTG      NaN               Work on the open issues of the MASVS
# 22           NaN      NaN                          Session on OWASP Honeypot
# 23   [Education]      NaN  Kick-off session for the new AppSec Curriculum...
# 24         [ZAP]      NaN                     Working session on the ZAP HUD
# 25         [ZAP]      NaN                  Working session on ZAP automation
# 26           NaN      NaN                                    Session on ASVS
# 27           NaN      NaN                Sessions on multiple OWASP Projects
# 28         [ZAP]      NaN                     User session to help ZAP users
# 29          None      NaN  Update project docs and plan the next phase of...
# ..           ...      ...                                                ...
# 84          None      NaN  Parallel editing session to improve the conten...
# 85          None      NaN  Discussion on the different SAMM documents and...
# 86          None      NaN  Parallel editing session to improve the conten...
# 87          None      NaN            Discussing outstanding model challenges
# 88          None      NaN  Aligning the SAMM model with the Threat Modeli...
# 89          None      NaN  Discussing the outreach for the OWASP SAMM pro...
# 90           NaN      NaN              Sessions focusing on OWASP Juice Shop
# 91           NaN      NaN            Go-live of new OWASP Juice Shop release
# 92           NaN      NaN              Round table of OWASP Juice Shop users
# 93           NaN      NaN          OWASP Juice Shop introduction for newbies
# 94           NaN      NaN  OWASP Juice Shop introduction for new contribu...
# 95           NaN      NaN  Refactoring the categories and difficulty rati...
# 96           NaN      NaN     Coding for and hacking of the OWASP Juice Shop
# 97           NaN      NaN               Sessions focusing on Threat Modeling
# 98          None      NaN  What is the current state of TM and where do w...
# 99          None      NaN  Discuss the SAMM threat modeling practice toge...
# 100        graph      NaN       Creating a generic diagram of a threat model
# 101         None      NaN  Introduction of the TM track and way of workin...
# 102         None      NaN  Lightweight privacy threat modeling using LIND...
# 103         None      NaN                       How to scale Threat Modeling
# 104         None      NaN                     Threat Library Working Session
# 105         None      NaN                                      Track closure
# 106         None      NaN  Discuss the OWASP Automated Threat Hunting Pro...
# 107         None      NaN  How do we persist the information from the TM ...
# 108         None      NaN  Lightweight privacy threat modeling using LINDDUN
# 109          NaN      NaN  Kick off of the OWASP Threat Model Examples Pr...
# 110          NaN      NaN                          Let's get some work done!
# 111         None      NaN               How do we measure the maturity of TM
# 112         None      NaN  A presentation and discussion of a new languag...
# 113          NaN      NaN  Sessions focusing on the strategic challenges ...
#
#     featured  host_link  host_text         layout locked  \
# 0       None        NaN        NaN            NaN    NaN
# 1        NaN        NaN        NaN    tracks-main    NaN
# 2        NaN        NaN        NaN  pages-details    NaN
# 3       True        NaN        NaN            NaN    NaN
# 4       None        NaN        NaN            NaN   True
# 5       True        NaN        NaN            NaN   True
# 6       True        NaN        NaN            NaN   True
# 7       True        NaN        NaN            NaN   True
# 8       True        NaN        NaN            NaN   True
# 9       True        NaN        NaN            NaN   True
# 10      True        NaN        NaN            NaN   True
# 11      None        NaN        NaN            NaN    NaN
# 12      None        NaN        NaN            NaN    NaN
# 13      True        NaN        NaN            NaN    NaN
# 14      None        NaN        NaN            NaN    NaN
# 15      True        NaN        NaN            NaN    NaN
# 16      None        NaN        NaN            NaN    NaN
# 17      True        NaN        NaN            NaN    NaN
# 18      True        NaN        NaN            NaN    NaN
# 19      None        NaN        NaN            NaN    NaN
# 20      True        NaN        NaN            NaN    NaN
# 21      True        NaN        NaN            NaN    NaN
# 22     False        NaN        NaN            NaN    NaN
# 23      True        NaN        NaN            NaN    NaN
# 24      True        NaN        NaN            NaN   True
# 25      True        NaN        NaN            NaN   True
# 26      True        NaN        NaN            NaN    NaN
# 27      True        NaN        NaN            NaN    NaN
# 28      True        NaN        NaN            NaN    NaN
# 29       NaN        NaN        NaN            NaN    NaN
# ..       ...        ...        ...            ...    ...
# 84      None        NaN        NaN            NaN   True
# 85      None        NaN        NaN            NaN   True
# 86      None        NaN        NaN            NaN   True
# 87      None        NaN        NaN            NaN   True
# 88      None        NaN        NaN            NaN   True
# 89      None        NaN        NaN            NaN   True
# 90      True        NaN        NaN            NaN    NaN
# 91     False        NaN        NaN            NaN    NaN
# 92      True        NaN        NaN            NaN    NaN
# 93      True        NaN        NaN            NaN    NaN
# 94      True        NaN        NaN            NaN    NaN
# 95      True        NaN        NaN            NaN    NaN
# 96      True        NaN        NaN            NaN    NaN
# 97      True        NaN        NaN            NaN    NaN
# 98      True        NaN        NaN            NaN   True
# 99      None        NaN        NaN            NaN   True
# 100     True        NaN        NaN            NaN   True
# 101     True        NaN        NaN            NaN   True
# 102     True        NaN        NaN            NaN   True
# 103     True        NaN        NaN            NaN   True
# 104     None        NaN        NaN            NaN    NaN
# 105     True        NaN        NaN            NaN   True
# 106     None        NaN        NaN            NaN  False
# 107     None        NaN        NaN            NaN   True
# 108     True        NaN        NaN            NaN   True
# 109     None        NaN        NaN            NaN    NaN
# 110     None        NaN        NaN            NaN    NaN
# 111     True        NaN        NaN            NaN   True
# 112     True        NaN        NaN            NaN   True
# 113     True        NaN        NaN            NaN    NaN
#
#                                             organizers owasp-project  ...  \
# 0                                                 None           NaN  ...
# 1                                                  NaN           NaN  ...
# 2                                                  NaN           NaN  ...
# 3                                            [Pending]         False  ...
# 4                         [Mario Platt, Tony Richards]           NaN  ...
# 5                        [Simon Wardley, Dave Snowden]           NaN  ...
# 6                                      [Tony Richards]           NaN  ...
# 7                                      [Simon Wardley]           NaN  ...
# 8                       [Tony Richards, Simon Wardley]           NaN  ...
# 9                                      [Simon Wardley]           NaN  ...
# 10                                     [Simon Wardley]           NaN  ...
# 11                                     [Tony Richards]           NaN  ...
# 12                                     [Tony Richards]           NaN  ...
# 13   [Jeroen Willemsen, Carlos Holguera, Sven Schle...           NaN  ...
# 14                                  [Jeroen Willemsen]           NaN  ...
# 15                                  [Jeroen Willemsen]           NaN  ...
# 16                                  [Jeroen Willemsen]           NaN  ...
# 17                                  [Jeroen Willemsen]           NaN  ...
# 18                                     [Sven Schleier]           NaN  ...
# 19                                   [Carlos Holguera]           NaN  ...
# 20                                     [Sven Schleier]           NaN  ...
# 21                                    [Jeroen Beckers]           NaN  ...
# 22                  [Felipe Zipitria, Adrian Winckles]           NaN  ...
# 23                       [Adrian Winckles, John DiLeo]           NaN  ...
# 24                                    [Simon Bennetts]           NaN  ...
# 25                                    [Simon Bennetts]           NaN  ...
# 26                                        [Jim Manico]           NaN  ...
# 27                                                None         False  ...
# 28                                                None          True  ...
# 29                                   [Jonathan Marcil]           NaN  ...
# ..                                                 ...           ...  ...
# 84               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 85               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 86               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 87               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 88               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 89               [Sebastien Deleersnyder, Bart De Win]           NaN  ...
# 90                                  [Bjoern Kimminich]          True  ...
# 91                                  [Bjoern Kimminich]           NaN  ...
# 92                                  [Bjoern Kimminich]           NaN  ...
# 93                                  [Bjoern Kimminich]           NaN  ...
# 94                                  [Bjoern Kimminich]           NaN  ...
# 95                                  [Bjoern Kimminich]           NaN  ...
# 96                                  [Bjoern Kimminich]           NaN  ...
# 97                                                None         False  ...
# 98                                    [Steven Wierckx]           NaN  ...
# 99            [Steven Wierckx, Sebastien Deleersnyder]           NaN  ...
# 100                                   [Steven Wierckx]           NaN  ...
# 101                                   [Steven Wierckx]           NaN  ...
# 102                        [Steven Wierckx, Kim Wuyts]           NaN  ...
# 103                    [Irene Michlin, Steven Wierckx]           NaN  ...
# 104                              [Steven van der Baan]           NaN  ...
# 105                                   [Steven Wierckx]           NaN  ...
# 106                      [Steven Wierckx, Tash Norris]           NaN  ...
# 107                                   [Steven Wierckx]           NaN  ...
# 108                        [Steven Wierckx, Kim Wuyts]           NaN  ...
# 109                     [Jonathan Marcil, Tash Norris]           NaN  ...
# 110                     [Jonathan Marcil, Tash Norris]           NaN  ...
# 111                                   [Steven Wierckx]           NaN  ...
# 112                                   [Steven Wierckx]           NaN  ...
# 113                                       [Nick Drage]           NaN  ...
#
#     session_type          status            technology  \
# 0            NaN           draft                  None
# 1            NaN             NaN                   NaN
# 2            NaN             NaN                   NaN
# 3            NaN             NaN                   NaN
# 4            NaN  review-content                  None
# 5            NaN           draft                  None
# 6            NaN  review-content                  None
# 7            NaN    need-content                  None
# 8            NaN            done                   NaN
# 9            NaN    need-content                  None
# 10           NaN    need-content                  None
# 11           NaN            done                  None
# 12           NaN            done                  None
# 13           NaN  review-content                Mobile
# 14           NaN  review-content                  None
# 15           NaN  review-content                  None
# 16           NaN  review-content                  None
# 17           NaN  review-content                  None
# 18           NaN  review-content           Mobile, iOS
# 19           NaN  review-content  Mobile, iOS, Android
# 20           NaN  review-content  Mobile, iOS, Android
# 21           NaN  review-content  Mobile, iOS, Android
# 22           NaN  review-content                   NaN
# 23           NaN  review-content                  None
# 24           NaN  review-content                  None
# 25           NaN  review-content                  None
# 26           NaN  review-content                   NaN
# 27           NaN             NaN                   NaN
# 28           NaN           draft                   NaN
# 29           NaN           draft                  None
# ..           ...             ...                   ...
# 84           NaN  review-content                  None
# 85           NaN  review-content                  None
# 86           NaN  review-content                  None
# 87           NaN  review-content                  None
# 88           NaN  review-content                  None
# 89           NaN  review-content                  None
# 90           NaN             NaN                   NaN
# 91           NaN  review-content                  None
# 92           NaN  review-content                  None
# 93           NaN  review-content                  None
# 94           NaN  review-content                  None
# 95           NaN  review-content                  None
# 96           NaN  review-content                  None
# 97           NaN             NaN                   NaN
# 98           NaN  review-content                  None
# 99           NaN  review-content                  None
# 100          NaN  review-content                  None
# 101          NaN  review-content                  None
# 102          NaN  review-content                  None
# 103          NaN  review-content                  None
# 104          NaN           draft          Threat Model
# 105          NaN            done                  None
# 106          NaN            done                  None
# 107          NaN  review-content                  None
# 108          NaN  review-content                  None
# 109          NaN            done         pytm,plantuml
# 110          NaN            done         pytm,plantuml
# 111          NaN  review-content                  None
# 112          NaN            done                  None
# 113          NaN             NaN                   NaN
#
#                                                  title  \
# 0                                                 None
# 1                                               Tracks
# 2                                                  NaN
# 3                                         Wardley Maps
# 4                            Wardley Maps for Security
# 5          Using Wardley Maps and Cynefin for Security
# 6                            Using Wardley Maps on SOC
# 7    Wardley Mapping - Coordinating functions withi...
# 8                   Cell based Structures for Security
# 9                                    Mapping boot camp
# 10   Wardley Mapping - Climatic Patterns and Using ...
# 11     Introduction to Wardley Maps (Training Session)
# 12   Hand's on Wardley Maps creation (Training Sess...
# 13                                          OWASP MSTG
# 14             OWASP Mobile Security Testing Guide 101
# 15            Mobile Security Testing Guide onboarding
# 16   OWASP Mobile Security Testing Guide 101 (Sessi...
# 17   Mobile Security Testing Guide onboarding (Sess...
# 18   Creating an iOS build pipeline with security c...
# 19   Mobile Basic Security Testing and Reverse Engi...
# 20   Android and iOS Security Enhancements and Crac...
# 21         Mobile AppSec Verification Standard (MASVS)
# 22                                      OWASP HoneyPot
# 23       OWASP Application Security Curriculum Project
# 24                       ZAP working session - the HUD
# 25                    ZAP working session - automation
# 26          Application Security Verification Standard
# 27                                      OWASP Projects
# 28                                 Zap - How to use it
# 29                                 OWASP Media Project
# ..                                                 ...
# 84                      SAMM - Model discussions (Tue)
# 85                    SAMM - Parallel editing (Thu PM)
# 86                       SAMM - Parallel editing (Tue)
# 87                       SAMM - Model Challenges (Wed)
# 88               SAMM - Alignment with Threat Modeling
# 89                       SAMM - Outreach program (Mon)
# 90                                    OWASP Juice Shop
# 91                            Juice Shop Release Night
# 92                              Juice Shop Round Table
# 93                                      Juice Shop 101
# 94                   Juice Shop Contributor Onboarding
# 95                    Juice Shop Challenge Refactoring
# 96                              Juice Shop Hack'n'Code
# 97                                        Threat Model
# 98                 State and future of threat modeling
# 99                            SAMMv2 - Threat Modeling
# 100       Creating a generic diagram of a threat model
# 101                              TM track introduction
# 102  Lightweight privacy threat modeling using LIND...
# 103                        Incremental Threat Modeling
# 104                          Creating a Threat Library
# 105                                      Track closure
# 106     Automated Threat Hunting Project Collaboration
# 107  How do we persist the information from the TM ...
# 108  Lightweight privacy threat modeling using LINDDUN
# 109               Threat Model Examples Project (PM-3)
# 110               Threat Model Examples Project (PM-2)
# 111                                        TM maturity
# 112  Towards a unified way of describing threat models
# 113                            Lessons from the Legion
#
#                                                 topics             track  \
# 0                                                 None               NaN
# 1                                                  NaN               NaN
# 2                                                  NaN               NaN
# 3                                                  NaN               NaN
# 4                                                  NaN      Wardley Maps
# 5                                                 None      Wardley Maps
# 6                                                 None      Wardley Maps
# 7                                                 None      Wardley Maps
# 8                                       [Wardley Maps]      Wardley Maps
# 9                                                 None      Wardley Maps
# 10                                                None      Wardley Maps
# 11                                                None      Wardley Maps
# 12                                                None      Wardley Maps
# 13                                     Mobile Security               NaN
# 14                                                None        OWASP MSTG
# 15                                                None        OWASP MSTG
# 16                                                None        OWASP MSTG
# 17                                                None        OWASP MSTG
# 18                                                 NaN        OWASP MSTG
# 19                                                 NaN        OWASP MSTG
# 20                                                 NaN        OWASP MSTG
# 21                                                 NaN        OWASP MSTG
# 22                                     [Owasp Project]    OWASP Projects
# 23   [Owasp Project, OWASP Application Security Cur...    OWASP Projects
# 24                                                 NaN    OWASP Projects
# 25                                                 NaN    OWASP Projects
# 26                                     [Owasp Project]    OWASP Projects
# 27                                                 NaN               NaN
# 28                                                 NaN    OWASP Projects
# 29                                                 NaN    OWASP Projects
# ..                                                 ...               ...
# 84                                                 NaN        OWASP SAMM
# 85                                                 NaN        OWASP SAMM
# 86                                                 NaN        OWASP SAMM
# 87                                                 NaN        OWASP SAMM
# 88                                                 NaN        OWASP SAMM
# 89                                                 NaN        OWASP SAMM
# 90                                                 NaN               NaN
# 91                                                None  OWASP Juice Shop
# 92                                                None  OWASP Juice Shop
# 93                                                None  OWASP Juice Shop
# 94                                                None  OWASP Juice Shop
# 95                                                None  OWASP Juice Shop
# 96                                                None  OWASP Juice Shop
# 97                                                 NaN               NaN
# 98                                                None      Threat Model
# 99                                                 NaN      Threat Model
# 100                                               None      Threat Model
# 101                                               None      Threat Model
# 102                                               None      Threat Model
# 103                                                NaN      Threat Model
# 104                                                NaN               NaN
# 105                                               None      Threat Model
# 106                                                NaN      Threat Model
# 107                                               None      Threat Model
# 108                                               None      Threat Model
# 109                                               None      Threat Model
# 110                                               None      Threat Model
# 111                                               None      Threat Model
# 112                                               None      Threat Model
# 113                                                NaN               NaN
#
#                 type       url                 when_day  \
# 0    working-session       NaN                     None
# 1                NaN  /tracks/                      NaN
# 2               json       NaN                      NaN
# 3              track       NaN              Mon,Tue,Wed
# 4       user-session       NaN                      Wed
# 5       user-session       NaN                      Wed
# 6       user-session       NaN                      Wed
# 7    working-session       NaN                      Thu
# 8    working-session       NaN                      Thu
# 9    working-session       NaN                      Thu
# 10   working-session       NaN                      Thu
# 11   working-session       NaN                      Mon
# 12   working-session       NaN                      Mon
# 13             track       NaN  Mon, Tue, Wed, Thu, Fri
# 14      user-session       NaN                      Mon
# 15      user-session       NaN                      Mon
# 16      user-session       NaN                      Wed
# 17      user-session       NaN                      Wed
# 18   working-session       NaN                      Wed
# 19   working-session       NaN          Mon,Tue,Wed,Thu
# 20   working-session       NaN      Mon,Tue,Wed,Thu,Fri
# 21   working-session       NaN                      Mon
# 22   working-session       NaN                      Wed
# 23   working-session       NaN                      Tue
# 24   working-session       NaN                      Tue
# 25   working-session       NaN                      Tue
# 26   working-session       NaN                      Wed
# 27             track       NaN              Mon,Wed,Fri
# 28      user-session       NaN                      Tue
# 29   working-session       NaN                 Tue, Wed
# ..               ...       ...                      ...
# 84   working-session       NaN                      Tue
# 85   working-session       NaN                      Thu
# 86   working-session       NaN                      Tue
# 87   working-session       NaN                      Wed
# 88   working-session       NaN                      Thu
# 89   working-session       NaN                      Mon
# 90             track       NaN          Mon,Tue,Wed,Thu
# 91      user-session       NaN                      Thu
# 92      user-session       NaN                      Thu
# 93      user-session       NaN                      Tue
# 94      user-session       NaN                      Tue
# 95   working-session       NaN                      Thu
# 96   working-session       NaN              Mon,Tue,Wed
# 97             track       NaN                  Wed,Thu
# 98   working-session       NaN                      Wed
# 99   working-session       NaN                      Thu
# 100  working-session       NaN                      Tue
# 101  working-session       NaN                      Mon
# 102  working-session       NaN                      Mon
# 103  working-session       NaN                      Thu
# 104  working-session       NaN                     None
# 105  working-session       NaN                      Thu
# 106  working-session       NaN                      Wed
# 107  working-session       NaN                      Tue
# 108  working-session       NaN                      Mon
# 109  working-session       NaN                      Tue
# 110  working-session       NaN                      Wed
# 111  working-session       NaN                      Tue
# 112  working-session       NaN                      Thu
# 113          keynote       NaN                      Mon
#
#                                 when_time
# 0                                    None
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                    PM-2
# 5                                    PM-2
# 6                                    PM-3
# 7                                    PM-3
# 8                                    PM-1
# 9                                    AM-1
# 10                                   PM-2
# 11                                   PM-1
# 12                                   PM-3
# 13                                   None
# 14                                   PM-1
# 15                                   PM-1
# 16                                   AM-1
# 17                                   AM-1
# 18                                   AM-1
# 19   AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 20   AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 21          AM-1, DS-2, PM-1, PM-2, Eve-1
# 22                                   PM-2
# 23                                   AM-1
# 24                                   PM-1
# 25                                   AM-1
# 26                                   PM-1
# 27                                    NaN
# 28                                  Eve-1
# 29                                  Eve-1
# ..                                    ...
# 84                                   PM-2
# 85                                   PM-1
# 86                                   PM-1
# 87                                   EV-1
# 88                                   PM-2
# 89                                   DS-2
# 90                                    NaN
# 91                           Eve-1, Eve-2
# 92                                   PM-2
# 93                                   AM-1
# 94                                   PM-1
# 95                                   AM-1
# 96                           Eve-1, Eve-2
# 97                                    NaN
# 98                                   AM-1
# 99                                   PM-3
# 100                                  PM-1
# 101                                  PM-1
# 102                                  PM-3
# 103                                  PM-1
# 104                                  None
# 105                                  PM-2
# 106                                  PM-2
# 107                                  AM-1
# 108                                  PM-2
# 109                                  PM-3
# 110                                  PM-3
# 111                                  PM-2
# 112                                  AM-1
# 113                                  DS-2
#
# [114 rows x 24 columns]

# %%
x[['description','when_day','when_time']]
# Out:
#                                            description  \
# 0                                                 None
# 1                                                  NaN
# 2                                                  NaN
# 3    Sessions focusing on the use of Wardley Maps i...
# 4    Practical session on using Wardley Maps for Se...
# 5    session on the intersection of Wardley Maps an...
# 6                                                 None
# 7     Coordinating functions within a PST organisation
# 8    Cell based Structures for Security - Small aut...
# 9    Wardely Mapping boot camp - Zero to Mapping He...
# 10   Wardley Mapping, Understanding Climatic Patter...
# 11        New to Wardley maps? This session is for you
# 12   Want to have a go at creating your own Wardley...
# 13        Sessions focusing on the OWASP MSTG project.
# 14   MSTG introduction for newbies (Two sessions av...
# 15   MSTG introduction for new contributors (Two se...
# 16   MSTG introduction for newbies (Two sessions av...
# 17   MSTG introduction for new contributors (Two se...
# 18   Brainstorming for a iOS pipeline with security...
# 19   Work on the Mobile Basic Security Testing and ...
# 20                    Updating the content of the MSTG
# 21                Work on the open issues of the MASVS
# 22                           Session on OWASP Honeypot
# 23   Kick-off session for the new AppSec Curriculum...
# 24                      Working session on the ZAP HUD
# 25                   Working session on ZAP automation
# 26                                     Session on ASVS
# 27                 Sessions on multiple OWASP Projects
# 28                      User session to help ZAP users
# 29   Update project docs and plan the next phase of...
# 30                Working sessions on ZAP future plans
# 31                     Collate results from Wednesday.
# 32   Practical Guide to Extending the Chaos Toolkit...
# 33                           Introduction and overview
# 34                            Session on Risk Modeling
# 35   Documents related to community outreach promot...
# 36   An exploration and working session to characte...
# 37          Session on problem and solution discussion
# 38    Hands on sessions of mapping GDPR data to graphs
# 39      Ask all the burning questions you have on GDPR
# 40                         Sessions on multiple topics
# 41                     Is this viable? Where do we go?
# 42   Next step, analyse cyber security in very gene...
# 43                                                None
# 44                                                None
# 45   New to Cynefin Framework? This session is for you
# 46                 What strategies are already in use?
# 47   Session on how to use Cynefin Framework making...
# 48   Sessions focusing on the DevSecOps tools and t...
# 49                                                None
# 50             Hands on session writing security tests
# 51                    AppSec Metrics and Visualisation
# 52   Integrate security tools as part of CI/CD pipe...
# 53                    DevSecOps Maturity Model (DSOMM)
# 54                                                None
# 55                                                 NaN
# 56                           Secure the CI/CD pipeline
# 57   How to deal with the security findings in an a...
# 58             Secrets Management in a DevSecOps world
# 59                  Agile Practices for Security Teams
# 60   SAMM team working together in a 5-day sprint o...
# 61      one of the 2 user sessions on the SAMM project
# 62         the onboarding session for the SAMM project
# 63      one of the 2 user sessions on the SAMM project
# 64   Discussing the outreach for the OWASP SAMM pro...
# 65         multiple working sessions on the new SAMMv2
# 66   Discussion on the new measurement model for th...
# 67       Aligning the model with other OWASP projects.
# 68   Discussion on the new measurement model for th...
# 69       Aligning the model with other OWASP projects.
# 70   Discussion on the different SAMM documents and...
# 71   Discussing the support for Agile development b...
# 72     Discussion on data collection and bench marking
# 73   Parallel editing session to improve the conten...
# 74             Spare session to cover any other topics
# 75   Parallel editing session to improve the conten...
# 76   Parallel editing session to improve the conten...
# 77       Aligning the model with other OWASP projects.
# 78             Spare session to cover any other topics
# 79   Deciding on the objectives and plans for outre...
# 80   Discussion on the different SAMM documents and...
# 81   Discussing the support for DevOps development ...
# 82   Discussion on the tools that we're making avai...
# 83             Discussing outstanding model challenges
# 84   Parallel editing session to improve the conten...
# 85   Discussion on the different SAMM documents and...
# 86   Parallel editing session to improve the conten...
# 87             Discussing outstanding model challenges
# 88   Aligning the SAMM model with the Threat Modeli...
# 89   Discussing the outreach for the OWASP SAMM pro...
# 90               Sessions focusing on OWASP Juice Shop
# 91             Go-live of new OWASP Juice Shop release
# 92               Round table of OWASP Juice Shop users
# 93           OWASP Juice Shop introduction for newbies
# 94   OWASP Juice Shop introduction for new contribu...
# 95   Refactoring the categories and difficulty rati...
# 96      Coding for and hacking of the OWASP Juice Shop
# 97                Sessions focusing on Threat Modeling
# 98   What is the current state of TM and where do w...
# 99   Discuss the SAMM threat modeling practice toge...
# 100       Creating a generic diagram of a threat model
# 101  Introduction of the TM track and way of workin...
# 102  Lightweight privacy threat modeling using LIND...
# 103                       How to scale Threat Modeling
# 104                     Threat Library Working Session
# 105                                      Track closure
# 106  Discuss the OWASP Automated Threat Hunting Pro...
# 107  How do we persist the information from the TM ...
# 108  Lightweight privacy threat modeling using LINDDUN
# 109  Kick off of the OWASP Threat Model Examples Pr...
# 110                          Let's get some work done!
# 111               How do we measure the maturity of TM
# 112  A presentation and discussion of a new languag...
# 113  Sessions focusing on the strategic challenges ...
#
#                     when_day                             when_time
# 0                       None                                  None
# 1                        NaN                                   NaN
# 2                        NaN                                   NaN
# 3                Mon,Tue,Wed                                   NaN
# 4                        Wed                                  PM-2
# 5                        Wed                                  PM-2
# 6                        Wed                                  PM-3
# 7                        Thu                                  PM-3
# 8                        Thu                                  PM-1
# 9                        Thu                                  AM-1
# 10                       Thu                                  PM-2
# 11                       Mon                                  PM-1
# 12                       Mon                                  PM-3
# 13   Mon, Tue, Wed, Thu, Fri                                  None
# 14                       Mon                                  PM-1
# 15                       Mon                                  PM-1
# 16                       Wed                                  AM-1
# 17                       Wed                                  AM-1
# 18                       Wed                                  AM-1
# 19           Mon,Tue,Wed,Thu  AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 20       Mon,Tue,Wed,Thu,Fri  AM-1, DS-2, PM-1, PM-2, Eve-1, Eve-2
# 21                       Mon         AM-1, DS-2, PM-1, PM-2, Eve-1
# 22                       Wed                                  PM-2
# 23                       Tue                                  AM-1
# 24                       Tue                                  PM-1
# 25                       Tue                                  AM-1
# 26                       Wed                                  PM-1
# 27               Mon,Wed,Fri                                   NaN
# 28                       Tue                                 Eve-1
# 29                  Tue, Wed                                 Eve-1
# 30                       Wed                                  AM-1
# 31                       Thu                                  PM-1
# 32                       Fri                                  PM-1
# 33                       Mon                                  PM-1
# 34                       Thu                                  PM-3
# 35                      None                           Eve-1,Eve-2
# 36                       Fri                                  PM-3
# 37                       Thu                                  DS-2
# 38                       Thu                                  PM-3
# 39                       Tue                                  PM-1
# 40               Mon,Wed,Fri                                   NaN
# 41                       Fri                                  PM-1
# 42                       Tue                                  PM-1
# 43                       Thu                                  DS-2
# 44                       Thu                                  DS-2
# 45                       Wed                                  AM-1
# 46                       Wed                                  None
# 47                       Wed                                  PM-1
# 48                   Wed,Thu                                  None
# 49                     Eve-2                                  None
# 50                       Thu                                  PM-1
# 51                       Wed                                  PM-1
# 52                       Thu                            AM-1, PM-1
# 53                       Tue                        PM-1,PM-2,PM-3
# 54                       Wed                                  AM-1
# 55                       Thu                                  PM-1
# 56                       Thu                             PM-2,PM-3
# 57                       Wed                             PM-1,PM-2
# 58                       Wed                                  PM-1
# 59                       Tue                                  PM-1
# 60               Tue,Wed,Thu                                   NaN
# 61                       Mon                                  PM-1
# 62                       Mon                                  AM-1
# 63                       Mon                                  PM-2
# 64                       Tue                                  DS-2
# 65                       Wed                                  PM-3
# 66                       Mon                                  EV-1
# 67                       Wed                                  DS-2
# 68                       Mon                                  PM-3
# 69                       Thu                                  DS-2
# 70                       Thu                                  AM-1
# 71                       Thu                                  EV-1
# 72                       Thu                                  PM-3
# 73                       Wed                                  PM-1
# 74                       Fri                                  PM-2
# 75                       Wed                                  PM-2
# 76                       Tue                                  AM-1
# 77                       Fri                                  DS-2
# 78                       Fri                                  PM-1
# 79                       Tue                                  PM-3
# 80                       Wed                                  AM-1
# 81                       Wed                                  PM-3
# 82                       Fri                                  AM-1
# 83                       Tue                                  EV-1
# 84                       Tue                                  PM-2
# 85                       Thu                                  PM-1
# 86                       Tue                                  PM-1
# 87                       Wed                                  EV-1
# 88                       Thu                                  PM-2
# 89                       Mon                                  DS-2
# 90           Mon,Tue,Wed,Thu                                   NaN
# 91                       Thu                          Eve-1, Eve-2
# 92                       Thu                                  PM-2
# 93                       Tue                                  AM-1
# 94                       Tue                                  PM-1
# 95                       Thu                                  AM-1
# 96               Mon,Tue,Wed                          Eve-1, Eve-2
# 97                   Wed,Thu                                   NaN
# 98                       Wed                                  AM-1
# 99                       Thu                                  PM-3
# 100                      Tue                                  PM-1
# 101                      Mon                                  PM-1
# 102                      Mon                                  PM-3
# 103                      Thu                                  PM-1
# 104                     None                                  None
# 105                      Thu                                  PM-2
# 106                      Wed                                  PM-2
# 107                      Tue                                  AM-1
# 108                      Mon                                  PM-2
# 109                      Tue                                  PM-3
# 110                      Wed                                  PM-3
# 111                      Tue                                  PM-2
# 112                      Thu                                  AM-1
# 113                      Mon                                  DS-2

# %%
pip install heysummit
# Out:
# WARNING: The directory '/home/jovyan/.cache/pip/http' or its parent directory is not owned by the current user and the cache has been disabled. Please check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# WARNING: The directory '/home/jovyan/.cache/pip' or its parent directory is not owned by the current user and caching wheels has been disabled. check the permissions and owner of that directory. If executing pip with sudo, you may want sudo's -H flag.
# Collecting heysummit
#   Downloading https://files.pythonhosted.org/packages/1e/c5/bbfa65b06514a030a2efacdc8606e685c66fbbc53eac4ba533461008aec2/heysummit-0.1.4-py3-none-any.whl
# Collecting requests<3.0.0,>=2.23.0 (from heysummit)
#   Downloading https://files.pythonhosted.org/packages/1a/70/1935c770cb3be6e3a8b78ced23d7e0f3b187f5cbfab4749523ed65d7c9b1/requests-2.23.0-py2.py3-none-any.whl (58kB)
#      |████████████████████████████████| 61kB 15.5MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.23.0->heysummit) (2019.3.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.23.0->heysummit) (2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.23.0->heysummit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.23.0->heysummit) (1.24.2)
# Installing collected packages: requests, heysummit
#   Found existing installation: requests 2.21.0
#     Uninstalling requests-2.21.0:
#       Successfully uninstalled requests-2.21.0
# Successfully installed heysummit-0.1.4 requests-2.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import argparse

from heysummit.api import HeySummit, HeySummitException

def list_attendees():
    attendees = hey.get_all_attendees()

    print("There are {n} attendees".format(len(attendees)))
    for attendee in attendees:
        print("id: {id}, email: {email}".format(
                id=attendee['id'], email=attendee['email']
                )
        )

def get_events():
    events = hey.get_events(is_live=True)

    for event in events:
        print(event)

# main

# Parse Arguments
parser = argparse.ArgumentParser(description='HeySummit interaction script.')
parser.add_argument('-t', '--token', type=str, help='API Token. Example: jdoe.', required=True)

# args = parser.parse_args()

# hey = HeySummit(token=args.token)

hey = HeySummit(token='6ad82d3fa6b4291066534585e6c89a623803ae73')

print(hey.get_attendees(event='iRYAOQy2'))

talks = hey.get_talks(event='5573', is_active=True)

for talk in talks:
    print(talk)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-7805bb8a0f05> in <module>
#      31 hey = HeySummit(token='6ad82d3fa6b4291066534585e6c89a623803ae73')
#      32
# ---> 33 print(hey.get_attendees(event='iRYAOQy2'))
#      34
#      35 # talks = hey.get_talks(event='iRYAOQy2', is_active=True)
#
# /opt/conda/lib/python3.7/site-packages/heysummit/api.py in get_attendees(self, event)
#     169         r.raise_for_status
#     170
# --> 171         return self._get_paged_results(response=r, params=params)
#     172
#     173     def get_attendee(self, id=None):
#
# /opt/conda/lib/python3.7/site-packages/heysummit/api.py in _get_paged_results(self, response, params)
#      45         """ Helper class for iterating over pages and returning all results """
#      46
# ---> 47         next_page = response.json()["next"]
#      48         results = response.json()["results"]
#      49
#
# KeyError: 'next'

# %%
import argparse

from heysummit.api import HeySummit, HeySummitException

def list_attendees():
    attendees = hey.get_all_attendees()

    print("There are {n} attendees".format(len(attendees)))
    for attendee in attendees:
        print("id: {id}, email: {email}".format(
                id=attendee['id'], email=attendee['email']
                )
        )

def get_events():
    events = hey.get_events(is_live=True)

    for event in events:
        print(event)

# main

# Parse Arguments
parser = argparse.ArgumentParser(description='HeySummit interaction script.')
parser.add_argument('-t', '--token', type=str, help='API Token. Example: jdoe.', required=True)

args = parser.parse_args('iE8YOYaR','45e765cc7371dfd723fe3ba7207dd29c5bc0333a')

# hey = HeySummit(token=args.token)

hey = HeySummit(token=args.token)

print(hey.get_all_attendees(event=5573))

talks = hey.get_talks(event=5573, is_active=True)

for talk in talks:
    print(talk)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-f8989d09b34e> in <module>
#      25 parser.add_argument('-t', '--token', type=str, help='API Token. Example: jdoe.', required=True)
#      26
# ---> 27 args = parser.parse_args('iE8YOYaR','45e765cc7371dfd723fe3ba7207dd29c5bc0333a')
#      28
#      29 # hey = HeySummit(token=args.token)
#
# /opt/conda/lib/python3.7/argparse.py in parse_args(self, args, namespace)
#    1747     # =====================================
#    1748     def parse_args(self, args=None, namespace=None):
# -> 1749         args, argv = self.parse_known_args(args, namespace)
#    1750         if argv:
#    1751             msg = _('unrecognized arguments: %s')
#
# /opt/conda/lib/python3.7/argparse.py in parse_known_args(self, args, namespace)
#    1770                 if not hasattr(namespace, action.dest):
#    1771                     if action.default is not SUPPRESS:
# -> 1772                         setattr(namespace, action.dest, action.default)
#    1773
#    1774         # add any parser defaults that aren't present
#
# AttributeError: 'str' object has no attribute 'token'

# %%
# hugo.df_merged_gsheet_and_hugo_data()
# hugo.participants_oss()

# %%
# hugo   = API_Hugo_OSS()
# #hugo.df_sessions(type='track')
# #hugo.df_sessions(type='working-session')['participants']
# mapping = []
# for path,session in hugo.sessions().items():
#     content      = session.get('content')
#     metadata     = session.get('metadata')
#     page_type    = metadata.get('type')
#     title        = metadata.get('title')
#     track        = metadata.get('track')
#     organizers   = metadata.get('organizers')
#     participants = metadata.get('participants')
#     if not organizers: organizers = []
#     if not participants: participants = []
#     if type(organizers)   is str: organizers   = organizers.split(',')
#     if type(participants) is str: participants = participants.split(',')
#     if 'TBD'     in organizers: organizers.remove('TBD')
#     if 'Pending' in organizers: organizers.remove('Pending')
#     if 'you ?'   in participants: participants.remove('you ?')
        
#     if title and page_type:
#         item = { 
#                     'title'       : title            , 
#                     'track'       : track            ,             
#                     'page_type'   : page_type        , 
#                     'organizers'  : organizers       , 
#                     'participants': participants     , 
#                     'content'     : len(content)     , 
#                     'path'        : path  
#         }
#         mapping.append(item)

# df_mappings = pd.DataFrame(mapping)
