# %%
import argparse

from heysummit.api import HeySummit, HeySummitException

def list_attendees():
    attendees = hey.get_all_attendees()

    print("There are {n} attendees".format(len(attendees)))
    for attendee in attendees:
        print("id: {id}, email: {email}".format(
                id=attendee['id'], email=attendee['email']
                )
        )

def get_events():
    events = hey.get_events(is_live=True)

    for event in events:
        print(event)

# %%
import pandas as pd

# %%
hey = HeySummit(token='6ad82d3fa6b4291066534585e6c89a623803ae73')

# print(hey.get_attendees(event='5573'))

df= pd.Dataframe(hey.get_attendees(event='5573'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-57fa814b6862> in <module>
#       3 # print(hey.get_attendees(event='5573'))
#       4
# ----> 5 df= pd.Dataframe(hey.get_attendees(event='5573'))
#
# TypeError: 'list' object is not callable

# %%
hey.get_attendees(event='5573')
# Out:
# [{'id': 1757659,
#   'url': 'https://api.heysummit.com/api/attendees/1757659/',
#   'email': 'roeyba5@gmail.com',
#   'name': 'Roey Barda',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T12:24:13.745429',
#   'questions': [{'attendee': 1757659,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1757659,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1757659,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Israel, Tel Aviv'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T12:24:19.397508'}]},
#  {'id': 1756764,
#   'url': 'https://api.heysummit.com/api/attendees/1756764/',
#   'email': 'kathryn_clark@blueyonder.co.uk',
#   'name': 'Kathryn Cardose',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T09:22:58.993231',
#   'questions': [{'attendee': 1756764,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1756764,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1756764,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Newcastle United Kingdom'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T09:23:02.443126'}]},
#  {'id': 1755307,
#   'url': 'https://api.heysummit.com/api/attendees/1755307/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T03:47:24.679969',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T04:34:11.350497'}]},
#  {'id': 1755305,
#   'url': 'https://api.heysummit.com/api/attendees/1755305/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T03:47:13.939596',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T04:34:11.003126'}]},
#  {'id': 1755291,
#   'url': 'https://api.heysummit.com/api/attendees/1755291/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T03:45:10.008841',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T04:17:08.521110'}]},
#  {'id': 1755288,
#   'url': 'https://api.heysummit.com/api/attendees/1755288/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T03:43:41.384789',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T04:17:08.209732'}]},
#  {'id': 1754832,
#   'url': 'https://api.heysummit.com/api/attendees/1754832/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T02:03:39.733941',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T02:34:13.063117'}]},
#  {'id': 1754820,
#   'url': 'https://api.heysummit.com/api/attendees/1754820/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T02:01:55.658706',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T02:34:12.715079'}]},
#  {'id': 1754817,
#   'url': 'https://api.heysummit.com/api/attendees/1754817/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T02:01:22.924114',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T02:34:12.383548'}]},
#  {'id': 1754811,
#   'url': 'https://api.heysummit.com/api/attendees/1754811/',
#   'email': 'felipe.zipitria+test@owasp.org',
#   'name': 'Felipe Zipitria API Test',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-31T01:59:55.880718',
#   'questions': [],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T02:34:12.035582'}]},
#  {'id': 1753991,
#   'url': 'https://api.heysummit.com/api/attendees/1753991/',
#   'email': 'andrew.byrne@dell.com',
#   'name': 'Andrew Byrne',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T23:25:17.179100',
#   'questions': [{'attendee': 1753991,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1753991,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1753991,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Ireland'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T23:25:24.615885'}]},
#  {'id': 1752670,
#   'url': 'https://api.heysummit.com/api/attendees/1752670/',
#   'email': 'caromoeckel@mac.com',
#   'name': 'Caroline Moeckel',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T20:07:24.372642',
#   'questions': [{'attendee': 1752670,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1752670,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1752670,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London, UK'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T23:22:17.651649'},
#    {'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T20:08:27.065155'}]},
#  {'id': 1752648,
#   'url': 'https://api.heysummit.com/api/attendees/1752648/',
#   'email': 'jo1072a@student.american.edu',
#   'name': "Jenna O'Connell",
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T20:06:59.468812',
#   'questions': [{'attendee': 1752648,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1752648,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1752648,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Yardley, PA'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T20:07:05.550294'}]},
#  {'id': 1752330,
#   'url': 'https://api.heysummit.com/api/attendees/1752330/',
#   'email': 'badzack@gmail.com',
#   'name': 'zack',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T19:14:44.070438',
#   'questions': [{'attendee': 1752330,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1752330,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1752330,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'paris'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T19:14:51.541074'}]},
#  {'id': 1752096,
#   'url': 'https://api.heysummit.com/api/attendees/1752096/',
#   'email': 'owasp@spamfree4now.com',
#   'name': None,
#   'registration_status': 'Registered',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T18:40:55.587556',
#   'questions': [],
#   'tickets': []},
#  {'id': 1751934,
#   'url': 'https://api.heysummit.com/api/attendees/1751934/',
#   'email': 'elie_gh16@hotmail.com',
#   'name': 'Elie',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T18:20:04.093232',
#   'questions': [{'attendee': 1751934,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751934,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751934,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Beirut'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T18:20:13.759478'}]},
#  {'id': 1751941,
#   'url': 'https://api.heysummit.com/api/attendees/1751941/',
#   'email': 'inbar.xo@gmail.com',
#   'name': 'Inbar',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T18:20:00.411060',
#   'questions': [{'attendee': 1751941,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751941,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751941,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Israel'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T18:20:31.518963'}]},
#  {'id': 1751908,
#   'url': 'https://api.heysummit.com/api/attendees/1751908/',
#   'email': 'pnraval2007@gmail.com',
#   'name': 'Neel Raval',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T18:14:23.712356',
#   'questions': [{'attendee': 1751908,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751908,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751908,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Banglore, India'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T18:14:31.617729'},
#    {'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T18:14:31.601805'}]},
#  {'id': 1751821,
#   'url': 'https://api.heysummit.com/api/attendees/1751821/',
#   'email': 'marsnik2@gmail.com',
#   'name': 'feli cat',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T18:04:14.459420',
#   'questions': [{'attendee': 1751821,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751821,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1751821,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Tel Aviv'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T18:04:20.111580'}]},
#  {'id': 1749472,
#   'url': 'https://api.heysummit.com/api/attendees/1749472/',
#   'email': 'arunvohra7@gmail.com',
#   'name': 'Arun Vohra',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T13:40:39.302036',
#   'questions': [{'attendee': 1749472,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1749472,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1749472,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T13:40:45.719366'}]},
#  {'id': 1749229,
#   'url': 'https://api.heysummit.com/api/attendees/1749229/',
#   'email': 'skriti@gmx.com',
#   'name': 'Kriti',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T13:14:26.891504',
#   'questions': [{'attendee': 1749229,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1749229,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1749229,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T13:17:18.163915'},
#    {'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': None,
#     'created_at': '2020-05-30T13:17:18.099920'},
#    {'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T13:16:17.136333'}]},
#  {'id': 1749067,
#   'url': 'https://api.heysummit.com/api/attendees/1749067/',
#   'email': 'want+price@ticketa.com',
#   'name': None,
#   'registration_status': 'Registered',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T12:54:07.570650',
#   'questions': [],
#   'tickets': []},
#  {'id': 1747871,
#   'url': 'https://api.heysummit.com/api/attendees/1747871/',
#   'email': 'raul.siles@gmail.com',
#   'name': 'Raul',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T09:14:06.903440',
#   'questions': [{'attendee': 1747871,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1747871,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1747871,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Spain'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-30T09:16:55.032678'}]},
#  {'id': 1744914,
#   'url': 'https://api.heysummit.com/api/attendees/1744914/',
#   'email': 'prasadnadkarni88@gmail.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Ticket',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-30T01:55:56.141598',
#   'questions': [],
#   'tickets': []},
#  {'id': 1742656,
#   'url': 'https://api.heysummit.com/api/attendees/1742656/',
#   'email': 'claudio.corridore@gmail.com',
#   'name': 'Claudio',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T22:10:53.815653',
#   'questions': [{'attendee': 1742656,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1742656,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1742656,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-29T22:11:01.164848'}]},
#  {'id': 1742670,
#   'url': 'https://api.heysummit.com/api/attendees/1742670/',
#   'email': 'lucian.corlan@owasp.org',
#   'name': 'Lucian Corlan',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T22:09:15.611517',
#   'questions': [{'attendee': 1742670,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1742670,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1742670,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London, UK'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-29T22:09:26.009933'}]},
#  {'id': 1742420,
#   'url': 'https://api.heysummit.com/api/attendees/1742420/',
#   'email': 'alexander.antukh@owasp.org',
#   'name': 'Alexander Antukh',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T21:45:16.516315',
#   'questions': [{'attendee': 1742420,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1742420,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1742420,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Warsaw'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-29T21:46:50.472948'}]},
#  {'id': 1734925,
#   'url': 'https://api.heysummit.com/api/attendees/1734925/',
#   'email': 'joshuajebaraj.z@gmail.com',
#   'name': 'joshua',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T14:46:24.192438',
#   'questions': [{'attendee': 1734925,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1734925,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1734925,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'India'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-31T02:36:36.603191'}]},
#  {'id': 1732010,
#   'url': 'https://api.heysummit.com/api/attendees/1732010/',
#   'email': 'mgreen@glasswallsolutions.com',
#   'name': 'Matthew Green',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T11:37:52.368317',
#   'questions': [{'attendee': 1732010,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1732010,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1732010,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'HALSTEAD, UK'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-29T11:40:24.695209'}]},
#  {'id': 1731807,
#   'url': 'https://api.heysummit.com/api/attendees/1731807/',
#   'email': 'bkubheka@glasswallsolutions.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Ticket',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T11:20:01.083921',
#   'questions': [],
#   'tickets': []},
#  {'id': 1731801,
#   'url': 'https://api.heysummit.com/api/attendees/1731801/',
#   'email': 'apeter@glasswallsolutions.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Ticket',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T11:19:16.834074',
#   'questions': [],
#   'tickets': []},
#  {'id': 1731199,
#   'url': 'https://api.heysummit.com/api/attendees/1731199/',
#   'email': 'hgeorgiou@glasswallsolutions.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Content',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T10:21:33.288357',
#   'questions': [],
#   'tickets': []},
#  {'id': 1731024,
#   'url': 'https://api.heysummit.com/api/attendees/1731024/',
#   'email': 'mazermac@gmail.com',
#   'name': 'Maria MacCallum',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T10:15:12.023359',
#   'questions': [{'attendee': 1731024,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1731024,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1731024,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'UK'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-29T10:15:20.725439'}]},
#  {'id': 1729024,
#   'url': 'https://api.heysummit.com/api/attendees/1729024/',
#   'email': 'sbimdad@yahoo.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Content',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T07:30:14.935598',
#   'questions': [],
#   'tickets': []},
#  {'id': 1725458,
#   'url': 'https://api.heysummit.com/api/attendees/1725458/',
#   'email': 'sean.finley@choicehotels.com',
#   'name': None,
#   'registration_status': 'Registered',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-29T00:44:19.638506',
#   'questions': [],
#   'tickets': []},
#  {'id': 1724610,
#   'url': 'https://api.heysummit.com/api/attendees/1724610/',
#   'email': 'dahoumane.mourad@gmail.com',
#   'name': None,
#   'registration_status': 'Registered',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T23:32:32.965577',
#   'questions': [],
#   'tickets': []},
#  {'id': 1723533,
#   'url': 'https://api.heysummit.com/api/attendees/1723533/',
#   'email': 'bjoern.kimminich@owasp.org',
#   'name': 'Björn Kimminich',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T22:25:11.122125',
#   'questions': [{'attendee': 1723533,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1723533,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1723533,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Hamburg, Germany'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T22:26:31.939370'}]},
#  {'id': 1719513,
#   'url': 'https://api.heysummit.com/api/attendees/1719513/',
#   'email': 'chandru.rt@gmail.com',
#   'name': 'Chandrasekar Rathinam',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T18:31:43.442943',
#   'questions': [{'attendee': 1719513,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1719513,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1719513,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Qatar'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T18:31:50.659697'}]},
#  {'id': 1719200,
#   'url': 'https://api.heysummit.com/api/attendees/1719200/',
#   'email': 'helen@ladieshackingsociety.com',
#   'name': 'Helen M',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T18:16:34.037574',
#   'questions': [{'attendee': 1719200,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1719200,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1719200,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T18:16:42.119599'}]},
#  {'id': 1718682,
#   'url': 'https://api.heysummit.com/api/attendees/1718682/',
#   'email': 'roupe.sahans@gmail.com',
#   'name': 'Roupe Sahans',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T17:53:26.937806',
#   'questions': [{'attendee': 1718682,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1718682,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1718682,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T17:55:14.488691'}]},
#  {'id': 1718445,
#   'url': 'https://api.heysummit.com/api/attendees/1718445/',
#   'email': 'kalvarez2390@gmail.com',
#   'name': 'Katherine Alvarez',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T17:41:14.017987',
#   'questions': [{'attendee': 1718445,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1718445,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1718445,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T17:41:22.943937'}]},
#  {'id': 1717577,
#   'url': 'https://api.heysummit.com/api/attendees/1717577/',
#   'email': 'ccampbell@tenable.com',
#   'name': 'Ciara Campbell',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T16:57:43.588015',
#   'questions': [{'attendee': 1717577,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717577,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717577,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Staines Upon Thames'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:57:48.748147'}]},
#  {'id': 1717520,
#   'url': 'https://api.heysummit.com/api/attendees/1717520/',
#   'email': 'shruti_s_kulkarni@yahoo.com',
#   'name': 'Shruti',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T16:53:30.282182',
#   'questions': [{'attendee': 1717520,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717520,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717520,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London, uk'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:53:35.253489'},
#    {'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:53:35.235226'}]},
#  {'id': 1717436,
#   'url': 'https://api.heysummit.com/api/attendees/1717436/',
#   'email': 'jennie.cox@gmail.com',
#   'name': 'Jennifer Cox',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T16:52:29.614653',
#   'questions': [{'attendee': 1717436,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717436,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717436,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Ireland'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:52:38.434330'}]},
#  {'id': 1717409,
#   'url': 'https://api.heysummit.com/api/attendees/1717409/',
#   'email': 'kathryn.waring@gmail.com',
#   'name': 'Kathryn',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T16:51:17.766152',
#   'questions': [{'attendee': 1717409,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717409,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1717409,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Guildford'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:51:24.510473'}]},
#  {'id': 1715498,
#   'url': 'https://api.heysummit.com/api/attendees/1715498/',
#   'email': 'michael@vr-security.com',
#   'name': 'Michael Man',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T16:20:42.161543',
#   'questions': [{'attendee': 1715498,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715498,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715498,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:20:47.445438'}]},
#  {'id': 1716559,
#   'url': 'https://api.heysummit.com/api/attendees/1716559/',
#   'email': 'swaleyb@hotmail.com',
#   'name': 'Claire Eccles',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T16:11:43.517207',
#   'questions': [{'attendee': 1716559,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1716559,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1716559,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Gloucester'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T16:11:47.312629'}]},
#  {'id': 1715542,
#   'url': 'https://api.heysummit.com/api/attendees/1715542/',
#   'email': 'mhai076@live.rhul.ac.uk',
#   'name': 'Anna',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T15:46:24.162358',
#   'questions': [{'attendee': 1715542,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715542,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm not cool"},
#    {'attendee': 1715542,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'UK'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:46:59.719289'}]},
#  {'id': 1715445,
#   'url': 'https://api.heysummit.com/api/attendees/1715445/',
#   'email': 'saranotaro@hotmail.it',
#   'name': 'Sara Notaro',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T15:44:06.149465',
#   'questions': [{'attendee': 1715445,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715445,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715445,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:44:11.179514'}]},
#  {'id': 1715400,
#   'url': 'https://api.heysummit.com/api/attendees/1715400/',
#   'email': 'kinnert.t@gmail.com',
#   'name': 'Tereza K',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T15:43:20.237301',
#   'questions': [{'attendee': 1715400,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715400,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715400,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:43:28.286024'}]},
#  {'id': 1715436,
#   'url': 'https://api.heysummit.com/api/attendees/1715436/',
#   'email': 'jlanine@hotmail.com',
#   'name': 'Janine',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T15:39:02.933374',
#   'questions': [{'attendee': 1715436,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715436,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm not cool"},
#    {'attendee': 1715436,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:39:06.346322'}]},
#  {'id': 1715275,
#   'url': 'https://api.heysummit.com/api/attendees/1715275/',
#   'email': 'heszterke@gmail.com',
#   'name': 'Eszter H',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T15:35:50.997555',
#   'questions': [{'attendee': 1715275,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715275,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715275,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:36:03.109753'}]},
#  {'id': 1715245,
#   'url': 'https://api.heysummit.com/api/attendees/1715245/',
#   'email': 'eliza@ladieshackingsociety.com',
#   'name': 'ELIZA AUSTIN',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T15:35:46.429590',
#   'questions': [{'attendee': 1715245,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715245,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1715245,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'doncaster'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:35:51.806588'}]},
#  {'id': 1712326,
#   'url': 'https://api.heysummit.com/api/attendees/1712326/',
#   'email': 'swierckx@gmail.com',
#   'name': 'Steven Wierckx',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T13:11:15.736082',
#   'questions': [{'attendee': 1712326,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1712326,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1712326,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Belgium'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T13:13:06.584234'}]},
#  {'id': 1712235,
#   'url': 'https://api.heysummit.com/api/attendees/1712235/',
#   'email': 'david0rosca@gmail.com',
#   'name': None,
#   'registration_status': 'Registered',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T13:04:46.284919',
#   'questions': [],
#   'tickets': []},
#  {'id': 1707253,
#   'url': 'https://api.heysummit.com/api/attendees/1707253/',
#   'email': 'timo.pagel@owasp.org',
#   'name': 'Timo Pagel',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T10:26:29.038511',
#   'questions': [{'attendee': 1707253,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1707253,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1707253,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Hamburg'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T10:26:46.138390'}]},
#  {'id': 1697958,
#   'url': 'https://api.heysummit.com/api/attendees/1697958/',
#   'email': 'mattia.rossi@ignitize.com.au',
#   'name': 'Mattia Rossi',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:27.667027'}]},
#  {'id': 1697959,
#   'url': 'https://api.heysummit.com/api/attendees/1697959/',
#   'email': 'simon.goldsmith@adidas.com',
#   'name': 'Simon Goldsmith',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:28.010825'}]},
#  {'id': 1697961,
#   'url': 'https://api.heysummit.com/api/attendees/1697961/',
#   'email': 'tony.richards@uk.ey.com',
#   'name': 'Tony Richards',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:28.376508'}]},
#  {'id': 1697962,
#   'url': 'https://api.heysummit.com/api/attendees/1697962/',
#   'email': 'hardword.sheen@gmail.com',
#   'name': 'Howard Shin',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:28.562780'}]},
#  {'id': 1697963,
#   'url': 'https://api.heysummit.com/api/attendees/1697963/',
#   'email': 'kd@vouchcom.com',
#   'name': 'Konstantinos Damianakis',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:28.763144'}]},
#  {'id': 1697964,
#   'url': 'https://api.heysummit.com/api/attendees/1697964/',
#   'email': 'jakub.kaluzny@securing.pl',
#   'name': 'Jakub Kaluzny',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:28.946521'}]},
#  {'id': 1697965,
#   'url': 'https://api.heysummit.com/api/attendees/1697965/',
#   'email': 'ethanms@gmail.com',
#   'name': 'Ethan Schorer',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-28T01:22:27.371554',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-28T01:22:29.138851'}]},
#  {'id': 1687937,
#   'url': 'https://api.heysummit.com/api/attendees/1687937/',
#   'email': 'michaelmorganelli@gmail.com',
#   'name': 'Michael Morganelli',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-27T13:18:55.688383',
#   'questions': [{'attendee': 1687937,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1687937,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1687937,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'New York'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-27T13:19:48.679784'}]},
#  {'id': 1687889,
#   'url': 'https://api.heysummit.com/api/attendees/1687889/',
#   'email': 'olegtaranenko@gmail.com',
#   'name': None,
#   'registration_status': 'Registered',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-27T13:12:38.177759',
#   'questions': [],
#   'tickets': []},
#  {'id': 1677806,
#   'url': 'https://api.heysummit.com/api/attendees/1677806/',
#   'email': 'lfservin+heysummit@gmail.com',
#   'name': 'Luis Servin',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
# ...
#   'url': 'https://api.heysummit.com/api/attendees/1582004/',
#   'email': 'fuerzademeiga@gmail.com',
#   'name': 'I Malinky',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-21T13:11:39.367345',
#   'questions': [{'attendee': 1582004,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1582004,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1582004,
#     'question': 'Which city, country are you attending from?',
#     'answer': ''}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-21T13:11:47.391388'}]},
#  {'id': 1578011,
#   'url': 'https://api.heysummit.com/api/attendees/1578011/',
#   'email': 'lianne.potter1@nhs.net',
#   'name': 'Lianne potter',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-21T09:54:07.027235',
#   'questions': [{'attendee': 1578011,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1578011,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1578011,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Uk'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-21T09:54:13.205476'}]},
#  {'id': 1578671,
#   'url': 'https://api.heysummit.com/api/attendees/1578671/',
#   'email': 'nch07878@gmail.com',
#   'name': 'NC',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-21T08:56:34.773876',
#   'questions': [{'attendee': 1578671,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1578671,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1578671,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'UK'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-21T08:56:49.610791'}]},
#  {'id': 1570503,
#   'url': 'https://api.heysummit.com/api/attendees/1570503/',
#   'email': 'gareth.evans@web46.co.uk',
#   'name': 'Gareth Evans',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T21:39:26.242583',
#   'questions': [{'attendee': 1570503,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1570503,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1570503,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Chester'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T17:11:43.150573'}]},
#  {'id': 1569767,
#   'url': 'https://api.heysummit.com/api/attendees/1569767/',
#   'email': 'roshni_mistry_123@hotmail.co.uk',
#   'name': 'Roshni Mistry',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T21:01:31.260874',
#   'questions': [{'attendee': 1569767,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1569767,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1569767,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London, UK'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T21:01:35.559263'}]},
#  {'id': 1569249,
#   'url': 'https://api.heysummit.com/api/attendees/1569249/',
#   'email': 'lpenhallow@gmail.com',
#   'name': 'Laura',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T20:33:19.779889',
#   'questions': [{'attendee': 1569249,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1569249,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1569249,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T20:33:26.413655'}]},
#  {'id': 1566984,
#   'url': 'https://api.heysummit.com/api/attendees/1566984/',
#   'email': 'bibisanjarani@gmail.com',
#   'name': 'Bibi Sanjarani',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T18:49:46.823773',
#   'questions': [{'attendee': 1566984,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1566984,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1566984,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London, UK'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T18:49:57.983833'}]},
#  {'id': 1566682,
#   'url': 'https://api.heysummit.com/api/attendees/1566682/',
#   'email': 'amal@walkfirst.com',
#   'name': 'Amal Kotecha',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T18:34:51.628571',
#   'questions': [{'attendee': 1566682,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1566682,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1566682,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'United Kingdom'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-28T15:36:12.061761'},
#    {'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T18:34:58.937849'}]},
#  {'id': 1382805,
#   'url': 'https://api.heysummit.com/api/attendees/1382805/',
#   'email': 'mhaltiner@gmail.com',
#   'name': 'Maia Haltiner',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T18:32:55.954133',
#   'questions': [{'attendee': 1382805,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1382805,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1382805,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Canada'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T18:35:37.402392'}]},
#  {'id': 1561654,
#   'url': 'https://api.heysummit.com/api/attendees/1561654/',
#   'email': 'sholaabhus@gmail.com',
#   'name': 'Shola',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T15:33:23.471551',
#   'questions': [{'attendee': 1561654,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1561654,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1561654,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Uk'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-27T22:16:30.127020'},
#    {'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T20:37:21.341965'},
#    {'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T20:37:21.296780'},
#    {'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T15:40:22.059268'}]},
#  {'id': 1557870,
#   'url': 'https://api.heysummit.com/api/attendees/1557870/',
#   'email': 'thelisafordham@gmail.com',
#   'name': 'Lisa Fordham',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T14:22:41.358706',
#   'questions': [{'attendee': 1557870,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1557870,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1557870,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'London'}],
#   'tickets': [{'ticket_id': 9421,
#     'ticket_name': 'Students and LLHS members',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T19:05:04.052021'}]},
#  {'id': 1551894,
#   'url': 'https://api.heysummit.com/api/attendees/1551894/',
#   'email': 'emilyyoung702@gmail.com',
#   'name': 'Emily Young',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-20T07:48:34.173412',
#   'questions': [{'attendee': 1551894,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1551894,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1551894,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Hitchin, England'}],
#   'tickets': [{'ticket_id': 9056,
#     'ticket_name': 'OWASP Leader/Member',
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-05-20T07:50:22.584459'}]},
#  {'id': 1448807,
#   'url': 'https://api.heysummit.com/api/attendees/1448807/',
#   'email': 'manntech2010@gmail.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Ticket',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-14T21:21:05.459137',
#   'questions': [],
#   'tickets': []},
#  {'id': 1434247,
#   'url': 'https://api.heysummit.com/api/attendees/1434247/',
#   'email': 'enrico.scichilone@kuehne-nagel.com',
#   'name': 'Enrico',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-14T07:47:14.839837',
#   'questions': [{'attendee': 1434247,
#     'question': 'Event Code of Conduct (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1434247,
#     'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)',
#     'answer': "I'm cool"},
#    {'attendee': 1434247,
#     'question': 'Which city, country are you attending from?',
#     'answer': 'Germany'}],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': 50.0,
#     'created_at': '2020-05-14T07:56:49.322691'}]},
#  {'id': 1420310,
#   'url': 'https://api.heysummit.com/api/attendees/1420310/',
#   'email': 'didadida@gmail.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Content',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-13T15:38:05.132720',
#   'questions': [],
#   'tickets': []},
#  {'id': 1401677,
#   'url': 'https://api.heysummit.com/api/attendees/1401677/',
#   'email': 'petra.v1986@gmail.com',
#   'name': 'Petra Vukmirovic',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-12T18:06:30.474585',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': None,
#     'created_at': '2020-05-12T18:15:09.272580'}]},
#  {'id': 1380683,
#   'url': 'https://api.heysummit.com/api/attendees/1380683/',
#   'email': 'felipe.zipitria@owasp.org',
#   'name': 'Felipe Zipitria',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-11T22:53:15.073199',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': None,
#     'created_at': '2020-05-12T12:18:18.655148'}]},
#  {'id': 1373620,
#   'url': 'https://api.heysummit.com/api/attendees/1373620/',
#   'email': 'j@77percent.com',
#   'name': None,
#   'registration_status': 'Checkout - Selected Content',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-11T17:15:09.472742',
#   'questions': [],
#   'tickets': []},
#  {'id': 1367866,
#   'url': 'https://api.heysummit.com/api/attendees/1367866/',
#   'email': 'didar.gelici@owasp.org',
#   'name': 'didar',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-11T12:49:51.383312',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': None,
#     'created_at': '2020-05-11T12:50:09.638353'}]},
#  {'id': 1367516,
#   'url': 'https://api.heysummit.com/api/attendees/1367516/',
#   'email': 'jemma@jemarketing.co.uk',
#   'name': 'Jemma Davis',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-05-11T12:29:52.062375',
#   'questions': [],
#   'tickets': [{'ticket_id': 8254,
#     'ticket_name': 'All Summit Sessions',
#     'amount_gross': 50.0,
#     'amount_net': None,
#     'created_at': '2020-05-11T12:30:06.397118'}]},
#  {'id': 1184872,
#   'url': 'https://api.heysummit.com/api/attendees/1184872/',
#   'email': 'dinis.cruz@owasp.org',
#   'name': 'Dinis Cruz',
#   'registration_status': 'Completed Order',
#   'event_id': 5573,
#   'event_name': 'Open Security Summit 2020',
#   'created_at': '2020-04-30T18:11:51.173283',
#   'questions': [],
#   'tickets': [{'ticket_id': None,
#     'ticket_name': None,
#     'amount_gross': None,
#     'amount_net': None,
#     'created_at': '2020-04-30T18:12:33.197275'}]}]
