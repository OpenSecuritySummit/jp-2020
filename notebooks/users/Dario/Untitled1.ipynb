# %%
import argparse

from heysummit.api import HeySummit, HeySummitException

def list_attendees():
    attendees = hey.get_all_attendees()

    print("There are {n} attendees".format(len(attendees)))
    for attendee in attendees:
        print("id: {id}, email: {email}".format(
                id=attendee['id'], email=attendee['email']
                )
        )

def get_events():
    events = hey.get_events(is_live=True)

    for event in events:
        print(event)

# %%
hey = HeySummit(token='6ad82d3fa6b4291066534585e6c89a623803ae73')

print(hey.get_attendees(event='5573'))

# talks = hey.get_talks(event='iRYAOQy2', is_active=True)

# for talk in talks:
#     print(talk)
# Out:
# [{'id': 1757659, 'url': 'https://api.heysummit.com/api/attendees/1757659/', 'email': 'roeyba5@gmail.com', 'name': 'Roey Barda', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T12:24:13.745429', 'questions': [{'attendee': 1757659, 'question': 'Event Code of Conduct (hover on the info icon to the right)', 'answer': "I'm cool"}, {'attendee': 1757659, 'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)', 'answer': "I'm cool"}, {'attendee': 1757659, 'question': 'Which city, country are you attending from?', 'answer': 'Israel, Tel Aviv'}], 'tickets': [{'ticket_id': 9421, 'ticket_name': 'Students and LLHS members', 'amount_gross': None, 'amount_net': None, 'created_at': '2020-05-31T12:24:19.397508'}]}, {'id': 1756764, 'url': 'https://api.heysummit.com/api/attendees/1756764/', 'email': 'kathryn_clark@blueyonder.co.uk', 'name': 'Kathryn Cardose', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T09:22:58.993231', 'questions': [{'attendee': 1756764, 'question': 'Event Code of Conduct (hover on the info icon to the right)', 'answer': "I'm cool"}, {'attendee': 1756764, 'question': 'The event will be video recorded and shared on social media afterwards (hover on the info icon to the right)', 'answer': "I'm cool"}, {'attendee': 1756764, 'question': 'Which city, country are you attending from?', 'answer': 'Newcastle United Kingdom'}], 'tickets': [{'ticket_id': 9421, 'ticket_name': 'Students and LLHS members', 'amount_gross': None, 'amount_net': None, 'created_at': '2020-05-31T09:23:02.443126'}]}, {'id': 1755307, 'url': 'https://api.heysummit.com/api/attendees/1755307/', 'email': 'felipe.zipitria+test@owasp.org', 'name': 'Felipe Zipitria API Test', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T03:47:24.679969', 'questions': [], 'tickets': [{'ticket_id': 9056, 'ticket_name': 'OWASP Leader/Member', 'amount_gross': None, 'amount_net': None, 'created_at': '2020-05-31T04:34:11.350497'}]}, {'id': 1755305, 'url': 'https://api.heysummit.com/api/attendees/1755305/', 'email': 'felipe.zipitria+test@owasp.org', 'name': 'Felipe Zipitria API Test', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T03:47:13.939596', 'questions': [], 'tickets': [{'ticket_id': 9056, 'ticket_name': 'OWASP Leader/Member', 'amount_gross': None, 'amount_net': None, 'created_at': '2020-05-31T04:34:11.003126'}]}, {'id': 1755291, 'url': 'https://api.heysummit.com/api/attendees/1755291/', 'email': 'felipe.zipitria+test@owasp.org', 'name': 'Felipe Zipitria API Test', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T03:45:10.008841', 'questions': [], 'tickets': [{'ticket_id': 9056, 'ticket_name': 'OWASP Leader/Member', 'amount_gross': None, 'amount_net': None, 'created_at': '2020-05-31T04:17:08.521110'}]}, {'id': 1755288, 'url': 'https://api.heysummit.com/api/attendees/1755288/', 'email': 'felipe.zipitria+test@owasp.org', 'name': 'Felipe Zipitria API Test', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T03:43:41.384789', 'questions': [], 'tickets': [{'ticket_id': 9056, 'ticket_name': 'OWASP Leader/Member', 'amount_gross': None, 'amount_net': None, 'created_at': '2020-05-31T04:17:08.209732'}]}, {'id': 1754832, 'url': 'https://api.heysummit.com/api/attendees/1754832/', 'email': 'felipe.zipitria+test@owasp.org', 'name': 'Felipe Zipitria API Test', 'registration_status': 'Completed Order', 'event_id': 5573, 'event_name': 'Open Security Summit 2020', 'created_at': '2020-05-31T02:03:39.733941', 'questions': [], 'tickets': [{'ticket_id': 9056, 'tick ...
