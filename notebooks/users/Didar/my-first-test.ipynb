# %%
# !jupyter labextension install jupyterlab-drawio
# Out:
# Node v11.14.0
#
# > /opt/conda/bin/npm pack jupyterlab-drawio
# npm notice
# npm notice 📦  jupyterlab-drawio@0.5.0
# npm notice === Tarball Contents ===
# npm notice 1.4kB   package.json
# npm notice 11.4kB  LICENSE.txt
# npm notice 961B    README.md
# npm notice 6.0kB   lib/editor.js
# npm notice 5.2kB   lib/index.js
# npm notice 80.2kB  lib/mxgraph/ChangeLog
# npm notice 4.2kB   lib/mxgraph/docs/css/manual-colors.css
# npm notice 3.6kB   lib/mxgraph/docs/css/manual-styles.css
# npm notice 27.7kB  lib/mxgraph/docs/images/architecture.png
# npm notice 21.5kB  lib/mxgraph/docs/images/callgraph.png
# npm notice 8.5kB   lib/mxgraph/docs/images/editor.png
# npm notice 7.5kB   lib/mxgraph/docs/images/graph.png
# npm notice 1.5kB   lib/mxgraph/docs/images/logo.jpg
# npm notice 14.0kB  lib/mxgraph/docs/images/model.png
# npm notice 27.7kB  lib/mxgraph/docs/images/mx_man_architecture.png
# npm notice 5.3kB   lib/mxgraph/docs/images/mx_man_collapse_swim.png
# ...

# %%
print(40+2)
# Out:
# 42

# %% [markdown]
# ## my first test
#
# this is some markdown
#
# - bullet 1
# - bullet 2
